# %%
#source data: https://github.com/orgtre/google-books-ngram-frequency/tree/main
#potential source https://github.com/krishnakt031990/Crawl-Wiki-For-Acronyms
#potential source https://blog.gdeltproject.org/announcing-the-new-web-news-ngrams-3-0-dataset/

# %%
import csv
from itertools import combinations

#Keys grouped by finger with the Colemak-DH layout
keygroup9 = {'q':'KC_Q','a':'KC_A','z':'KC_Z'}
keygroup7 = {'w':'KC_W','r':'KC_R','x':'KC_X'}
keygroup5 = {'f':'KC_F','s':'KC_S','c':'KC_C'}
keygroup3 = {'p':'KC_P','t':'KC_T','d':'KC_D','b':'KC_B','g':'KC_G','v':'KC_V'}
keygroup2 = {'j':'KC_J','m':'KC_M','k':'KC_K','l':'KC_L','n':'KC_N','h':'KC_H'}
keygroup4 = {'u':'KC_U','e':'KC_E'}
keygroup6 = {'y':'KC_Y','i':'KC_I'}
keygroup8 = {';':'KC_SCLN','o':'KC_O','/':'KC_SLSH',"'":'KC_QUOT','-':'KC_MINS'}

#how many do you want to return
combo_list_limit = 2000

#A thumb key that can be used in combos without affecting typing (tab, enter or a function key could also work)
#Change to None if this will not work for your keyboard
#Using a function key could allow 2 key combos for heavy typing but it is a large investment for such a valuable position
special_key = 'KC_BSPC'
#special_key = None

#space will use the other thumb
space_key = 'KC_SPC'

#force abbreviations for known issues/preferances
item_abrevs = {
    ("k", "b"): "keyboard",
    ("k", "b", " "): "keyboard ",
    ("k", "y", " "): "key ",
    # SQL
    ("s", "l", " "): "select ",
    ("w", "e", " "): "where ",
    ("u", "p", " "): "update ",
    ("a", "p", " "): "append ",
    ("c", "t", " "): "create ",
    ("i", "s", " "): "insert ",
    ("d", "a", "s"): "database",
    ("d", "e", " "): "delete ",
    ("g", "y", " "): "group by ",
    ("h", "g", " "): "having ",
    ("l", "e", " "): "like ",
    ("o", "b", " "): "order by ",
    ("d", "s", " "): "distinct ",
    ("v", "l", " "): "values ",
    ("u", "n", " "): "union ",
    ("t", "l", " "): "table ",
    ("j", "o", " "): "join ",
    # Python
    ("t", "u", " "): "True ",
    ("f", "l", " "): "False ",
    ("v", "l", "u"): "value",
    ("n", "e", " "): "none ",
    ("w", "l", " "): "while ",
    ("e", "f", " "): "elif ",
    ("e", "l", "s"): "else",
    ("e", "x", "c"): "except",
    ("l", "d", " "): "lambda ",
}

left_groups = [1, 3, 5, 7, 9]
right_groups = [0, 2, 4, 6, 8]

usable_keys = {}
usable_keys[' '] = {'kc': space_key, 'group': 0}
usable_keys[special_key] = {'kc': special_key, 'group': 1}

for key, val in keygroup2.items():
    usable_keys[key] = {'kc': val, 'group': 2}
for key, val in keygroup3.items():
    usable_keys[key] = {'kc': val, 'group': 3}
for key, val in keygroup4.items():
    usable_keys[key] = {'kc': val, 'group': 4}
for key, val in keygroup5.items():
    usable_keys[key] = {'kc': val, 'group': 5}
for key, val in keygroup6.items():
    usable_keys[key] = {'kc': val, 'group': 6}
for key, val in keygroup7.items():
    usable_keys[key] = {'kc': val, 'group': 7}
for key, val in keygroup8.items():
    usable_keys[key] = {'kc': val, 'group': 8}
for key, val in keygroup9.items():
    usable_keys[key] = {'kc': val, 'group': 9}

# %%
def get_gram_dict(file, dictname):
    with open(file, mode ='r')as file:
        csvFile = csv.reader(file)
        i = 0
        for lines in csvFile:
            if i > 0:
                word = lines[0] + " "
                dictname[word] = int(lines[1])
            i += 1

# %%
def check_combo(combo):
    check = True
    if len(combo) == 2:
        let1 = combo[0]
        let2 = combo[1]
        check_set1 = let1+let2
        check_set2 = let2+let1
        if check_set1 in shinglesk2 or check_set2 in shinglesk2:
            check = False
        elif usable_keys[let1]['group'] == usable_keys[let2]['group']:
            check = False
        elif combo in abrevs_list:
            check = False
    elif len(combo) >= 3:
        letter_groups = []
        for let in combo:
            if usable_keys[let]['group'] in letter_groups:
                check = False
            letter_groups.append(usable_keys[let]['group'])
        if check is True:
            #ban pinky finger if 2 other fingers on the same hand are already used, might be ok if all are on the same row
            if 8 in letter_groups:
                right_count = 0
                for group_num in letter_groups:
                    if group_num in right_groups:
                        right_count += 1
                if right_count > 2 :
                    check = False
            if 9 in letter_groups:
                left_count = 0
                for group_num in letter_groups:
                    if group_num in left_groups:
                        left_count += 1
                if left_count > 2:
                    check = False
        if check is True:
            if combo in abrevs_list:
                check = False
    return check

# %%
ngrams1 = {}
ngrams2 = {}
ngrams3 = {}
ngrams4 = {}
ngrams5 = {}
shingles = {}
shinglesk2 = set()
letter_ranks = {}

get_gram_dict('1grams_english.csv', ngrams1)
get_gram_dict('2grams_english.csv', ngrams2)
get_gram_dict('3grams_english.csv', ngrams3)
get_gram_dict('4grams_english.csv', ngrams4)
get_gram_dict('5grams_english.csv', ngrams5)


for word, freq in ngrams1.items():
    for let in word:
        let = let.lower()
        if let in letter_ranks:
            letter_ranks[let] += freq
        else:
            letter_ranks[let] = freq
    if len(word) > 3:
        word_len = len(word)
        for start in range(word_len-1):
            end = start + 2
            shingle = word[start:end].lower()
            shinglesk2.add(shingle)
        for k in range(3, word_len):
            shingle_count = word_len - k
            for start in range(shingle_count+1):
                end = start + k
                shingle = word[start:end].lower()
                if shingle in shingles:
                    shingles[shingle] += freq
                else:
                    shingles[shingle] = freq

candidate_dict = {**ngrams1, **ngrams2, **ngrams3, **ngrams4, **ngrams5}
for shingle, freq in shingles.items():
    if shingle in candidate_dict:
        candidate_dict[shingle] += freq
    else:
        candidate_dict[shingle] = freq

candidate_scores = {}
for key, val in candidate_dict.items():
    if len(key) > 2:
        score = (len(key)-2) * val
        candidate_scores[key] = score


max_score = max(candidate_scores.values())
for key, val in candidate_scores.items():
    candidate_scores[key] = val / max_score

# %%
ngrams1f = {}
ngrams2f = {}
ngrams3f = {}
ngrams4f = {}
ngrams5f = {}
shingles = {}
#we can just use the first dataset to find letters that are never adjcent
#shinglesk2 = set()
letter_ranks = {}

get_gram_dict('1grams_english-fiction.csv', ngrams1f)
get_gram_dict('2grams_english-fiction.csv', ngrams2f)
get_gram_dict('3grams_english-fiction.csv', ngrams3f)
get_gram_dict('4grams_english-fiction.csv', ngrams4f)
get_gram_dict('5grams_english-fiction.csv', ngrams5f)


for word, freq in ngrams1f.items():
    for let in word:
        let = let.lower()
        if let in letter_ranks:
            letter_ranks[let] += freq
        else:
            letter_ranks[let] = freq
    if len(word) > 3:
        word_len = len(word)
        #for start in range(word_len-1):
        #    end = start + 2
        #    shingle = word[start:end].lower()
        #    shinglesk2.add(shingle)
        for k in range(3, word_len):
            shingle_count = word_len - k
            for start in range(shingle_count+1):
                end = start + k
                shingle = word[start:end].lower()
                if shingle in shingles:
                    shingles[shingle] += freq
                else:
                    shingles[shingle] = freq

candidate_dict2 = {**ngrams1f, **ngrams2f, **ngrams3f, **ngrams4f, **ngrams5f}
for shingle, freq in shingles.items():
    if shingle in candidate_dict2:
        candidate_dict2[shingle] += freq
    else:
        candidate_dict2[shingle] = freq

candidate_scores2 = {}
for key, val in candidate_dict2.items():
    if len(key) > 2:
        score = (len(key)-2) * val
        candidate_scores2[key] = score

max_score = max(candidate_scores2.values())
for key, val in candidate_scores2.items():
    #candidate_scores2[key] = val / max_score
    if key not in candidate_scores.keys():
        candidate_scores[key] = val / max_score * 0.5
    else:
        candidate_scores[key] = (candidate_scores[key] * 0.5) + ((val / max_score) * 0.5)

for key in candidate_scores.keys():
    if key not in candidate_scores2.keys():
        candidate_scores[key] = candidate_scores[key] * 0.5

# %%
#get items from forced user preferances
abrevs_list = []
for key in item_abrevs.keys():
    abrevs_list.append(key)

sorted_candidate_scores = sorted(candidate_scores.items(), key=lambda x:x[1], reverse=True)

abrevs_list = []
for key in item_abrevs.keys():
    abrevs_list.append(key)

letter_ranks[' '] = -99999999
letter_ranks['KC_BSPC'] = -9999

for items in sorted_candidate_scores:
    item = items[0]
    #check if new item is just part of a higher scored existing item, ex. if we already have 'between' then ignore 'etween'
    used = False
    for old_item in item_abrevs.values():
        len_diff = len(old_item) - len(item)
        if len_diff > 0:
            for start in range(len_diff + 1):
                end = len(old_item) - len_diff + start
                check = old_item[start:end]
                if check == item:
                    used = True
                    break
    if len(item) > 2 and used == False:
        """combo = tuple
        if special_key is not None:
            combo = (item[0].lower(), special_key)
            combo = tuple(sorted(combo))
        if combo not in abrevs_list and special_key is not None:
            item_abrevs[combo] = item
            abrevs_list.append(combo)
        else:"""
        temp_dict = {}
        temp_groups = []
        combo_len = 1
        temp_dict2 = {}
        f_letter = item[0].lower()
        if f_letter in usable_keys.keys():
            f_letter_group = usable_keys[f_letter]['group']
            temp_groups.append(f_letter_group)
            for letter in item[1:]:
                letter = letter.lower()
                if letter in usable_keys.keys() and letter != f_letter:
                    letter_group = usable_keys[letter]['group']
                    if letter_group != f_letter_group:
                        temp_dict[letter] = letter_ranks[letter]
                    temp_dict2[letter] = letter_ranks[letter]
        combo_found = False
        if len(temp_dict.keys()) == 0:
            combo_found = True
        while combo_found is False:
            if len(abrevs_list) >= combo_list_limit:
                combo_found = True
            else:
                #try to get 2 letter combos when both keys are never consecutive in a word
                if combo_len == 1:
                    cand_key = min(temp_dict, key=temp_dict.get)
                    del temp_dict[cand_key]
                    combo = (f_letter, cand_key)
                    combo = tuple(sorted(combo))
                    check_res = check_combo(combo)
                elif len(temp_dict) > 0 and combo_len > 1:
                    combo = min(temp_dict, key=temp_dict.get)
                    del temp_dict[combo]
                    combo = tuple(sorted(combo))
                    if combo_len >= len(item):
                        check_res = False
                    else:
                        check_res = check_combo(combo)
                if check_res is True:
                    item_abrevs[combo] = item
                    abrevs_list.append(combo)
                    combo_found = True

                elif len(temp_dict.keys()) == 0 and combo_len == 1:
                    combo_len = 2
                    temp_dict = {}
                    temp_combos = combinations(list(temp_dict2.keys()), 2)
                    for combo in temp_combos:
                        temp_dict[combo] = temp_dict2[combo[0]] + temp_dict2[combo[1]]
                elif len(temp_dict.keys()) == 0 and combo_len == 2:
                    combo_len = 3
                    temp_dict = {}
                    temp_dict2[f_letter] = -9999
                    #bias towards first letters all words
                    word_start = False
                    for check_letter in item:
                        check_letter = check_letter.lower()
                        if word_start is True:
                            temp_dict2[check_letter] = -9999
                        if check_letter == ' ':
                            temp_dict2[' '] = letter_ranks[check_letter]
                            word_start = True
                        else:
                            word_start = False
                    if special_key is not None:
                        temp_dict2[special_key] = letter_ranks[special_key]
                    temp_combos = combinations(list(temp_dict2.keys()), 3)
                    for combo in temp_combos:
                        temp_dict[combo] = temp_dict2[combo[0]] + temp_dict2[combo[1]] + temp_dict2[combo[2]]
                elif len(temp_dict.keys()) == 0 and combo_len == 3:
                    combo_found = True

print(item_abrevs)
# Out:
# {('k', 'b'): 'keyboard', ('k', 'b', ' '): 'keyboard ', ('k', 'y', ' '): 'key ', ('s', 'l', ' '): 'select ', ('w', 'e', ' '): 'where ', ('u', 'p', ' '): 'update ', ('a', 'p', ' '): 'append ', ('c', 't', ' '): 'create ', ('i', 's', ' '): 'insert ', ('d', 'a', 's'): 'database', ('d', 'e', ' '): 'delete ', ('g', 'y', ' '): 'group by ', ('h', 'g', ' '): 'having ', ('l', 'e', ' '): 'like ', ('o', 'b', ' '): 'order by ', ('d', 's', ' '): 'distinct ', ('v', 'l', ' '): 'values ', ('u', 'n', ' '): 'union ', ('t', 'l', ' '): 'table ', ('j', 'o', ' '): 'join ', ('t', 'u', ' '): 'True ', ('f', 'l', ' '): 'False ', ('v', 'l', 'u'): 'value', ('n', 'e', ' '): 'none ', ('w', 'l', ' '): 'while ', ('e', 'f', ' '): 'elif ', ('e', 'l', 's'): 'else', ('e', 'x', 'c'): 'except', ('l', 'd', ' '): 'lambda ', (' ', 'KC_BSPC', 't'): 'the ', (' ', 'KC_BSPC', 'a'): 'and ', (' ', 'h', 't'): 'that ', (' ', 'o', 't'): 'of the ', (' ', 'KC_BSPC', 'h'): 'her ', (' ', 'h', 's'): 'his ', (' ', 'i', 't'): 'tion ', (' ', 'KC_BSPC', 'w'): 'was ', (' ', 'i', 'w'): 'with ', (' ', 'KC_BSPC', 'i'): 'in the ', (' ', 'KC_BSPC', 'n'): 'not ', (' ', 'KC_BSPC', 'y'): 'you ', (' ', 'KC_BSPC', 'o'): 'ould ', ('KC_BSPC', 'r', 't'): 'ther', (' ', 'KC_BSPC', 's'): 'she ', (' ', 'KC_BSPC', 'f'): 'for ', ('KC_BSPC', 'a', 'i'): 'ation', (' ', 'r', 't'): 'ther ', (' ', 'a', 'i'): 'ation ', ('KC_BSPC', 'h', 't'): 'to the ', (' ', 's', 't'): 'this ', (' ', 'KC_BSPC', 'e'): 'ent ', (' ', 'f', 'm'): 'from ', ('h', 'v'): 'have ', (' ', 'd', 'h'): 'had ', (' ', 't', 'y'): 'they ', (' ', 'KC_BSPC', 'd'): 'ted ', (' ', 'KC_BSPC', 'u'): 'out ', (' ', 'u', 'w'): 'would ', (' ', 'o', 'r'): 'other ', (' ', 'g', 'i'): 'ight ', ('KC_BSPC', 'o', 't'): 'on the ', (' ', 'KC_BSPC', 'r'): 'there ', (' ', 'KC_BSPC', 'g'): 'thing ', (' ', 'a', 't'): 'and the ', (' ', 'KC_BSPC', 'b'): 'but ', (' ', 'a', 'l'): 'all ', (' ', 'KC_BSPC', 'c'): 'could ', (' ', 'h', 'w'): 'what ', (' ', 'e', 't'): 'ter ', (' ', 'e', 'h'): 'hen ', ('KC_BSPC', 'i', 't'): 'their ', (' ', 'e', 'w'): 'were ', (' ', 'd', 's'): 'said ', (' ', 'n', 't'): 'ting ', (' ', 'a', 'b'): 'about ', (' ', 'f', 't'): 'from the ', (' ', 'a', 'r'): 'are ', (' ', 'c', 'n'): 'nce ', (' ', 'd', 'n'): 'did not ', ('KC_BSPC', 'i', 'w'): 'it was ', (' ', 'KC_BSPC', 'k'): 'king ', (' ', 'KC_BSPC', 'v'): 'ver ', (' ', 'KC_BSPC', 'm'): 'ment ', (' ', 'd', 'r'): 'red ', ('KC_BSPC', 'g', 'o'): 'ough', ('c', 'w'): 'which ', (' ', 'a', 'h'): 'at the ', (' ', 't', 'w'): 'with the ', ('KC_BSPC', 'f', 't'): 'for the ', (' ', 'e', 'n'): 'een ', (' ', 'n', 'w'): 'when ', ('KC_BSPC', 'o', 'r'): 'ore ', ('KC_BSPC', 's', 't'): 'tions ', (' ', 'h', 'i'): 'him ', (' ', 'g', 'o'): 'ough ', ('KC_BSPC', 'o', 'u'): 'our ', ('KC_BSPC', 'e', 'v'): 'ever', ('KC_BSPC', 't', 'u'): 'though', ('KC_BSPC', 'd', 'n'): 'do not ', ('KC_BSPC', 'e', 'n'): 'ned ', (' ', 'd', 'o'): 'ound ', (' ', 'd', 'i'): 'ding ', (' ', 'i', 'l'): 'ill ', (' ', 'g', 'n'): 'ning ', (' ', 'b', 'n'): 'been ', ('KC_BSPC', 'd', 's'): 'sed ', (' ', 'a', 'y'): 'ally ', ('KC_BSPC', 'm', 'o'): 'ome ', (' ', 't', 'u'): 'through ', (' ', 'd', 'k'): 'ked ', (' ', 'g', 's'): 'something ', (' ', 'i', 'n'): 'into ', (' ', 'KC_BSPC', 'l'): 'like ', (' ', 'm', 't'): 'them ', (' ', 'c', 'i'): 'ction ', ('KC_BSPC', 'h', 'w'): 'he was ', ('KC_BSPC', 'n', 'w'): 'now ', (' ', 'e', 'v'): 'ever ', (' ', 'b', 'o'): 'to be ', (' ', 'e', 'r'): 'ers ', (' ', 'm', 'r'): 'more ', (' ', 'o', 'w'): 'own ', ('KC_BSPC', 'n', 't'): 'then ', ('b', 'f'): 'before ', (' ', 'u', 'y'): 'your ', (' ', 'g', 'r'): 'ring ', (' ', 'l', 'w'): 'will ', ('KC_BSPC', 'm', 't'): 'time ', ('i', 'n', 't'): 'into the ', ('b', 'k'): 'back ', ('b', 'c'): 'because ', (' ', 'e', 's'): 'ess ', (' ', 'i', 'v'): 'ive ', ('KC_BSPC', 'e', 't'): 'that the ', (' ', 'd', 'l'): 'led ', (' ', 's', 'w'): 'she was ', ('KC_BSPC', 'o', 'v'): 'over', (' ', 'r', 'u'): 'round ', (' ', 's', 'u'): 'ust ', ('KC_BSPC', 'c', 'n'): 'can ', (' ', 'o', 'v'): 'over ', (' ', 'h', 'r'): 'wh ...

# %%
i = 0
for key in abrevs_list:
    val = item_abrevs[key]
    i += 1
    combo_id = "0000" + str(i)
    trim_len = len(combo_id) - 4
    combo_id = "COMBO" + combo_id[trim_len:]
    combo_keys = ""
    for key_entry in key:
        code = usable_keys[key_entry]['kc']
        combo_keys = combo_keys + code + ", "
    combo_keys = combo_keys[:-2]
    print("SUBS(" + combo_id + ',  "' + val + '",  ' + combo_keys + ")")
# Out:
# SUBS(COMBO0001,  "keyboard",  KC_K, KC_B)
# SUBS(COMBO0002,  "keyboard ",  KC_K, KC_B, KC_SPC)
# SUBS(COMBO0003,  "key ",  KC_K, KC_Y, KC_SPC)
# SUBS(COMBO0004,  "select ",  KC_S, KC_L, KC_SPC)
# SUBS(COMBO0005,  "where ",  KC_W, KC_E, KC_SPC)
# SUBS(COMBO0006,  "update ",  KC_U, KC_P, KC_SPC)
# SUBS(COMBO0007,  "append ",  KC_A, KC_P, KC_SPC)
# SUBS(COMBO0008,  "create ",  KC_C, KC_T, KC_SPC)
# SUBS(COMBO0009,  "insert ",  KC_I, KC_S, KC_SPC)
# SUBS(COMBO0010,  "database",  KC_D, KC_A, KC_S)
# SUBS(COMBO0011,  "delete ",  KC_D, KC_E, KC_SPC)
# SUBS(COMBO0012,  "group by ",  KC_G, KC_Y, KC_SPC)
# SUBS(COMBO0013,  "having ",  KC_H, KC_G, KC_SPC)
# SUBS(COMBO0014,  "like ",  KC_L, KC_E, KC_SPC)
# SUBS(COMBO0015,  "order by ",  KC_O, KC_B, KC_SPC)
# SUBS(COMBO0016,  "distinct ",  KC_D, KC_S, KC_SPC)
# SUBS(COMBO0017,  "values ",  KC_V, KC_L, KC_SPC)
# SUBS(COMBO0018,  "union ",  KC_U, KC_N, KC_SPC)
# SUBS(COMBO0019,  "table ",  KC_T, KC_L, KC_SPC)
# SUBS(COMBO0020,  "join ",  KC_J, KC_O, KC_SPC)
# SUBS(COMBO0021,  "True ",  KC_T, KC_U, KC_SPC)
# SUBS(COMBO0022,  "False ",  KC_F, KC_L, KC_SPC)
# SUBS(COMBO0023,  "value",  KC_V, KC_L, KC_U)
# SUBS(COMBO0024,  "none ",  KC_N, KC_E, KC_SPC)
# SUBS(COMBO0025,  "while ",  KC_W, KC_L, KC_SPC)
# SUBS(COMBO0026,  "elif ",  KC_E, KC_F, KC_SPC)
# SUBS(COMBO0027,  "else",  KC_E, KC_L, KC_S)
# SUBS(COMBO0028,  "except",  KC_E, KC_X, KC_C)
# SUBS(COMBO0029,  "lambda ",  KC_L, KC_D, KC_SPC)
# SUBS(COMBO0030,  "the ",  KC_SPC, KC_BSPC, KC_T)
# SUBS(COMBO0031,  "and ",  KC_SPC, KC_BSPC, KC_A)
# SUBS(COMBO0032,  "that ",  KC_SPC, KC_H, KC_T)
# SUBS(COMBO0033,  "of the ",  KC_SPC, KC_O, KC_T)
# SUBS(COMBO0034,  "her ",  KC_SPC, KC_BSPC, KC_H)
# SUBS(COMBO0035,  "his ",  KC_SPC, KC_H, KC_S)
# SUBS(COMBO0036,  "tion ",  KC_SPC, KC_I, KC_T)
# SUBS(COMBO0037,  "was ",  KC_SPC, KC_BSPC, KC_W)
# SUBS(COMBO0038,  "with ",  KC_SPC, KC_I, KC_W)
# SUBS(COMBO0039,  "in the ",  KC_SPC, KC_BSPC, KC_I)
# SUBS(COMBO0040,  "not ",  KC_SPC, KC_BSPC, KC_N)
# SUBS(COMBO0041,  "you ",  KC_SPC, KC_BSPC, KC_Y)
# SUBS(COMBO0042,  "ould ",  KC_SPC, KC_BSPC, KC_O)
# SUBS(COMBO0043,  "ther",  KC_BSPC, KC_R, KC_T)
# SUBS(COMBO0044,  "she ",  KC_SPC, KC_BSPC, KC_S)
# SUBS(COMBO0045,  "for ",  KC_SPC, KC_BSPC, KC_F)
# SUBS(COMBO0046,  "ation",  KC_BSPC, KC_A, KC_I)
# SUBS(COMBO0047,  "ther ",  KC_SPC, KC_R, KC_T)
# SUBS(COMBO0048,  "ation ",  KC_SPC, KC_A, KC_I)
# SUBS(COMBO0049,  "to the ",  KC_BSPC, KC_H, KC_T)
# SUBS(COMBO0050,  "this ",  KC_SPC, KC_S, KC_T)
# SUBS(COMBO0051,  "ent ",  KC_SPC, KC_BSPC, KC_E)
# SUBS(COMBO0052,  "from ",  KC_SPC, KC_F, KC_M)
# SUBS(COMBO0053,  "have ",  KC_H, KC_V)
# SUBS(COMBO0054,  "had ",  KC_SPC, KC_D, KC_H)
# SUBS(COMBO0055,  "they ",  KC_SPC, KC_T, KC_Y)
# SUBS(COMBO0056,  "ted ",  KC_SPC, KC_BSPC, KC_D)
# SUBS(COMBO0057,  "out ",  KC_SPC, KC_BSPC, KC_U)
# SUBS(COMBO0058,  "would ",  KC_SPC, KC_U, KC_W)
# SUBS(COMBO0059,  "other ",  KC_SPC, KC_O, KC_R)
# SUBS(COMBO0060,  "ight ",  KC_SPC, KC_G, KC_I)
# SUBS(COMBO0061,  "on the ",  KC_BSPC, KC_O, KC_T)
# SUBS(COMBO0062,  "there ",  KC_SPC, KC_BSPC, KC_R)
# SUBS(COMBO0063,  "thing ",  KC_SPC, KC_BSPC, KC_G)
# SUBS(COMBO0064,  "and the ",  KC_SPC, KC_A, KC_T)
# SUBS(COMBO0065,  "but ",  KC_SPC, KC_BSPC, KC_B)
# SUBS(COMBO0066,  "all ",  KC_SPC, KC_A, KC_L)
# SUBS(COMBO0067,  "could ",  KC_SPC, KC_BSPC, KC_C)
# SUBS(COMBO0068,  "what ",  KC_SPC, KC_H, KC_W)
# SUBS(COMBO0069,  "ter ",  KC_SPC, KC_E, KC_T)
# SUBS(COMBO0070,  "hen ",  KC_SPC, KC_E, KC_H)
# SUBS(COMBO0071,  "their ",  KC_BSPC, KC_I, KC_T)
# SUBS(COMBO0072,  "were ",  KC_SPC, KC_E, KC_W)
# SUBS(COMBO0073,  "said ",  KC_SPC, KC_D, KC_S)
# SUBS(COMBO0074,  "ting ",  KC_SPC, KC_N, KC_T)
# SUBS(COMBO0075,  "about ",  KC_SPC, KC_A, KC_B)
# SUBS(COMBO0076,  "from the ",  KC_SPC, KC_F, KC_T)
# SUBS(COMBO0077,  "are ",  KC_SPC, KC_A, KC_R)
# SUBS(COMBO0078,  "nce ",  KC_SPC, KC_C, KC_N)
# SUBS(COMBO0079,  "did not ",  KC_SPC, KC_D, KC_N)
# SUBS(COMBO0080,  "it was ",  KC_BSPC, KC_I, KC_W)
# SUBS(COMBO0081,  "king ",  KC_SPC, KC_BSPC, KC_K)
# SUBS(COMBO0082,  "ver ",  KC_SPC, KC_BSPC, KC_V)
# SUBS(COMBO0083,  "ment ",  KC_SPC, KC_BSPC, KC_M)
# SUBS(COMBO0084,  "red ",  KC_SPC, KC_D, KC_R)
# SUBS(COMBO0085,  "ough",  KC_BSPC, KC_G, KC_O)
# SUBS(COMBO0086,  "which ",  KC_C, KC_W)
# SUBS(COMBO0087,  "at the ",  KC_SPC, KC_A, KC_H)
# SUBS(COMBO0088,  "with the ",  KC_SPC, KC_T, KC_W)
# SUBS(COMBO0089,  "for the ",  KC_BSPC, KC_F, KC_T)
# SUBS(COMBO0090,  "een ",  KC_SPC, KC_E, KC_N)
# SUBS(COMBO0091,  "when ",  KC_SPC, KC_N, KC_W)
# SUBS(COMBO0092,  "ore ",  KC_BSPC, KC_O, KC_R)
# SUBS(COMBO0093,  "tions ",  KC_BSPC, KC_S, KC_T)
# SUBS(COMBO0094,  "him ",  KC_SPC, KC_H, KC_I)
# SUBS(COMBO0095,  "ough ",  KC_SPC, KC_G, KC_O)
# SUBS(COMBO0096,  "our ",  KC_BSPC, KC_O, KC_U)
# SUBS(COMBO0097,  "ever",  KC_BSPC, KC_E, KC_V)
# SUBS(COMBO0098,  "though",  KC_BSPC, KC_T, KC_U)
# SUBS(COMBO0099,  "do not ",  KC_BSPC, KC_D, KC_N)
# SUBS(COMBO0100,  "ned ",  KC_BSPC, KC_E, KC_N)
# SUBS(COMBO0101,  "ound ",  KC_SPC, KC_D, KC_O)
# SUBS(COMBO0102,  "ding ",  KC_SPC, KC_D, KC_I)
# SUBS(COMBO0103,  "ill ",  KC_SPC, KC_I, KC_L)
# SUBS(COMBO0104,  "ning ",  KC_SPC, KC_G, KC_N)
# SUBS(COMBO0105,  "been ",  KC_SPC, KC_B, KC_N)
# SUBS(COMBO0106,  "sed ",  KC_BSPC, KC_D, KC_S)
# SUBS(COMBO0107,  "ally ",  KC_SPC, KC_A, KC_Y)
# SUBS(COMBO0108,  "ome ",  KC_BSPC, KC_M, KC_O)
# SUBS(COMBO0109,  "through ",  KC_SPC, KC_T, KC_U)
# SUBS(COMBO0110,  "ked ",  KC_SPC, KC_D, KC_K)
# SUBS(COMBO0111,  "something ",  KC_SPC, KC_G, KC_S)
# SUBS(COMBO0112,  "into ",  KC_SPC, KC_I, KC_N)
# SUBS(COMBO0113,  "like ",  KC_SPC, KC_BSPC, KC_L)
# SUBS(COMBO0114,  "them ",  KC_SPC, KC_M, KC_T)
# SUBS(COMBO0115,  "ction ",  KC_SPC, KC_C, KC_I)
# SUBS(COMBO0116,  "he was ",  KC_BSPC, KC_H, KC_W)
# SUBS(COMBO0117,  "now ",  KC_BSPC, KC_N, KC_W)
# SUBS(COMBO0118,  "ever ",  KC_SPC, KC_E, KC_V)
# SUBS(COMBO0119,  "to be ",  KC_SPC, KC_B, KC_O)
# SUBS(COMBO0120,  "ers ",  KC_SPC, KC_E, KC_R)
# SUBS(COMBO0121,  "more ",  KC_SPC, KC_M, KC_R)
# SUBS(COMBO0122,  "own ",  KC_SPC, KC_O, KC_W)
# SUBS(COMBO0123,  "then ",  KC_BSPC, KC_N, KC_T)
# SUBS(COMBO0124,  "before ",  KC_B, KC_F)
# SUBS(COMBO0125,  "your ",  KC_SPC, KC_U, KC_Y)
# SUBS(COMBO0126,  "ring ",  KC_SPC, KC_G, KC_R)
# SUBS(COMBO0127,  "will ",  KC_SPC, KC_L, KC_W)
# SUBS(COMBO0128,  "time ",  KC_BSPC, KC_M, KC_T)
# SUBS(COMBO0129,  "into the ",  KC_I, KC_N, KC_T)
# SUBS(COMBO0130,  "back ",  KC_B, KC_K)
# SUBS(COMBO0131,  "because ",  KC_B, KC_C)
# SUBS(COMBO0132,  "ess ",  KC_SPC, KC_E, KC_S)
# SUBS(COMBO0133,  "ive ",  KC_SPC, KC_I, KC_V)
# SUBS(COMBO0134,  "that the ",  KC_BSPC, KC_E, KC_T)
# SUBS(COMBO0135,  "led ",  KC_SPC, KC_D, KC_L)
# SUBS(COMBO0136,  "she was ",  KC_SPC, KC_S, KC_W)
# SUBS(COMBO0137,  "over",  KC_BSPC, KC_O, KC_V)
# SUBS(COMBO0138,  "round ",  KC_SPC, KC_R, KC_U)
# SUBS(COMBO0139,  "ust ",  KC_SPC, KC_S, KC_U)
# SUBS(COMBO0140,  "can ",  KC_BSPC, KC_C, KC_N)
# SUBS(COMBO0141,  "over ",  KC_SPC, KC_O, KC_V)
# SUBS(COMBO0142,  "where ",  KC_SPC, KC_H, KC_R)
# SUBS(COMBO0143,  "ered ",  KC_SPC, KC_D, KC_E)
# SUBS(COMBO0144,  "had been ",  KC_SPC, KC_B, KC_H)
# SUBS(COMBO0145,  "ence ",  KC_SPC, KC_C, KC_E)
# SUBS(COMBO0146,  "ought ",  KC_SPC, KC_G, KC_U)
# SUBS(COMBO0147,  "ure ",  KC_BSPC, KC_R, KC_U)
# SUBS(COMBO0148,  "ity ",  KC_BSPC, KC_T, KC_Y)
# SUBS(COMBO0149,  "thought ",  KC_BSPC, KC_G, KC_U)
# SUBS(COMBO0150,  "just ",  KC_SPC, KC_J)
# SUBS(COMBO0151,  "ain ",  KC_SPC, KC_A, KC_N)
# SUBS(COMBO0152,  "self ",  KC_SPC, KC_L, KC_S)
# SUBS(COMBO0153,  "com",  KC_C, KC_M)
# SUBS(COMBO0154,  "was not ",  KC_SPC, KC_N, KC_S)
# SUBS(COMBO0155,  "could not ",  KC_SPC, KC_N, KC_U)
# SUBS(COMBO0156,  "ded ",  KC_BSPC, KC_D, KC_E)
# SUBS(COMBO0157,  "after ",  KC_SPC, KC_A, KC_F)
# SUBS(COMBO0158,  "ell ",  KC_SPC, KC_E, KC_L)
# SUBS(COMBO0159,  "very ",  KC_SPC, KC_V, KC_Y)
# SUBS(COMBO0160,  "right ",  KC_BSPC, KC_G, KC_R)
# SUBS(COMBO0161,  "should",  KC_BSPC, KC_S, KC_U)
# SUBS(COMBO0162,  "there was ",  KC_BSPC, KC_T, KC_W)
# SUBS(COMBO0163,  "way ",  KC_SPC, KC_W, KC_Y)
# SUBS(COMBO0164,  "with a ",  KC_SPC, KC_A, KC_W)
# SUBS(COMBO0165,  "know ",  KC_SPC, KC_K, KC_W)
# SUBS(COMBO0166,  "some ",  KC_SPC, KC_M, KC_S)
# SUBS(COMBO0167,  "ance ",  KC_SPC, KC_A, KC_C)
# SUBS(COMBO0168,  "ling ",  KC_SPC, KC_G, KC_L)
# SUBS(COMBO0169,  "by the ",  KC_SPC, KC_B, KC_Y)
# SUBS(COMBO0170,  "people ",  KC_SPC, KC_BSPC, KC_P)
# SUBS(COMBO0171,  "little ",  KC_BSPC, KC_I, KC_L)
# SUBS(COMBO0172,  "again",  KC_BSPC, KC_A, KC_N)
# SUBS(COMBO0173,  "ents ",  KC_BSPC, KC_E, KC_S)
# SUBS(COMBO0174,  "ant ",  KC_A, KC_N, KC_T)
# SUBS(COMBO0175,  "should ",  KC_BSPC, KC_L, KC_S)
# SUBS(COMBO0176,  "around ",  KC_SPC, KC_A, KC_U)
# SUBS(COMBO0177,  "ies ",  KC_SPC, KC_I, KC_S)
# SUBS(COMBO0178,  "ame ",  KC_SPC, KC_A, KC_M)
# SUBS(COMBO0179,  "through the ",  KC_R, KC_T, KC_U)
# SUBS(COMBO0180,  "only ",  KC_BSPC, KC_O, KC_Y)
# SUBS(COMBO0181,  "look",  KC_BSPC, KC_L, KC_O)
# SUBS(COMBO0182,  "between ",  KC_SPC, KC_B, KC_W)
# SUBS(COMBO0183,  "first ",  KC_SPC, KC_F, KC_R)
# SUBS(COMBO0184,  "ations ",  KC_SPC, KC_A, KC_S)
# SUBS(COMBO0185,  "sion ",  KC_BSPC, KC_I, KC_S)
# SUBS(COMBO0186,  "ated ",  KC_SPC, KC_A, KC_D)
# SUBS(COMBO0187,  "down ",  KC_SPC, KC_D, KC_W)
# SUBS(COMBO0188,  "ace ",  KC_SPC, KC_A, KC_E)
# SUBS(COMBO0189,  "looked ",  KC_BSPC, KC_D, KC_L)
# SUBS(COMBO0190,  "he had ",  KC_BSPC, KC_D, KC_H)
# SUBS(COMBO0191,  "man ",  KC_BSPC, KC_A, KC_M)
# SUBS(COMBO0192,  "ood ",  KC_BSPC, KC_D, KC_O)
# SUBS(COMBO0193,  "hed ",  KC_BSPC, KC_E, KC_H)
# SUBS(COMBO0194,  "any ",  KC_BSPC, KC_A, KC_Y)
# SUBS(COMBO0195,  "ake ",  KC_SPC, KC_A, KC_K)
# SUBS(COMBO0196,  "another ",  KC_BSPC, KC_A, KC_H)
# SUBS(COMBO0197,  "they were ",  KC_T, KC_W, KC_Y)
# SUBS(COMBO0198,  "side",  KC_D, KC_I, KC_S)
# SUBS(COMBO0199,  "ything ",  KC_SPC, KC_G, KC_Y)
# SUBS(COMBO0200,  "than ",  KC_A, KC_H, KC_T)
# SUBS(COMBO0201,  "even ",  KC_SPC, KC_N, KC_V)
# SUBS(COMBO0202,  "ead ",  KC_BSPC, KC_A, KC_E)
# SUBS(COMBO0203,  "though ",  KC_SPC, KC_G, KC_H)
# SUBS(COMBO0204,  "going to ",  KC_BSPC, KC_G, KC_I)
# SUBS(COMBO0205,  "these ",  KC_H, KC_S, KC_T)
# SUBS(COMBO0206,  "ide ",  KC_BSPC, KC_D, KC_I)
# SUBS(COMBO0207,  "the same ",  KC_M, KC_S, KC_T)
# SUBS(COMBO0208,  "uch ",  KC_SPC, KC_C, KC_U)
# SUBS(COMBO0209,  "ice ",  KC_BSPC, KC_C, KC_I)
# SUBS(COMBO0210,  "side ",  KC_D, KC_E, KC_S)
# SUBS(COMBO0211,  "ose ",  KC_SPC, KC_O, KC_S)
# SUBS(COMBO0212,  "ook ",  KC_BSPC, KC_K, KC_O)
# SUBS(COMBO0213,  "I do not ",  KC_D, KC_I, KC_N)
# SUBS(COMBO0214,  "est ",  KC_E, KC_S, KC_T)
# SUBS(COMBO0215,  "who ",  KC_BSPC, KC_O, KC_W)
# SUBS(COMBO0216,  "ind ",  KC_BSPC, KC_I, KC_N)
# SUBS(COMBO0217,  "ather ",  KC_A, KC_H, KC_R)
# SUBS(COMBO0218,  "have been ",  KC_BSPC, KC_B, KC_H)
# SUBS(COMBO0219,  "come ",  KC_SPC, KC_C, KC_M)
# SUBS(COMBO0220,  "ical ",  KC_SPC, KC_C, KC_L)
# SUBS(COMBO0221,  "think ",  KC_SPC, KC_K, KC_T)
# SUBS(COMBO0222,  "inte",  KC_BSPC, KC_E, KC_I)
# SUBS(COMBO0223,  "of his ",  KC_BSPC, KC_H, KC_O)
# SUBS(COMBO0224,  "lled ",  KC_BSPC, KC_E, KC_L)
# SUBS(COMBO0225,  "ong ",  KC_BSPC, KC_N, KC_O)
# SUBS(COMBO0226,  "out of ",  KC_SPC, KC_F, KC_O)
# SUBS(COMBO0227,  "never ",  KC_BSPC, KC_N, KC_V)
# SUBS(COMBO0228,  "the first ",  KC_F, KC_R, KC_T)
# SUBS(COMBO0229,  "still ",  KC_I, KC_L, KC_S)
# SUBS(COMBO0230,  "the other ",  KC_O, KC_R, KC_T)
# SUBS(COMBO0231,  "every",  KC_BSPC, KC_E, KC_Y)
# SUBS(COMBO0232,  "old ",  KC_D, KC_L, KC_O)
# SUBS(COMBO0233,  "would be ",  KC_BSPC, KC_B, KC_W)
# SUBS(COMBO0234,  "tional ",  KC_SPC, KC_L, KC_T)
# SUBS(COMBO0235,  "ying ",  KC_BSPC, KC_G, KC_Y)
# SUBS(COMBO0236,  "again ",  KC_SPC, KC_A, KC_G)
# SUBS(COMBO0237,  "how ",  KC_H, KC_O, KC_W)
# SUBS(COMBO0238,  "long ",  KC_BSPC, KC_G, KC_L)
# SUBS(COMBO0239,  "differen",  KC_BSPC, KC_D, KC_F)
# SUBS(COMBO0240,  "ear ",  KC_BSPC, KC_E, KC_R)
# SUBS(COMBO0241,  "she had ",  KC_BSPC, KC_H, KC_S)
# SUBS(COMBO0242,  "in a ",  KC_A, KC_I, KC_N)
# SUBS(COMBO0243,  "turned ",  KC_SPC, KC_D, KC_U)
# SUBS(COMBO0244,  "ection ",  KC_BSPC, KC_C, KC_E)
# SUBS(COMBO0245,  "ture ",  KC_E, KC_R, KC_T)
# SUBS(COMBO0246,  "nder",  KC_BSPC, KC_N, KC_R)
# SUBS(COMBO0247,  "against ",  KC_BSPC, KC_G, KC_S)
# SUBS(COMBO0248,  "ely ",  KC_SPC, KC_E, KC_Y)
# SUBS(COMBO0249,  "sing ",  KC_BSPC, KC_N, KC_S)
# SUBS(COMBO0250,  "without ",  KC_BSPC, KC_U, KC_W)
# SUBS(COMBO0251,  "tive ",  KC_BSPC, KC_I, KC_V)
# SUBS(COMBO0252,  "it is ",  KC_I, KC_S, KC_T)
# SUBS(COMBO0253,  "nter",  KC_N, KC_R, KC_T)
# SUBS(COMBO0254,  "most ",  KC_BSPC, KC_M, KC_S)
# SUBS(COMBO0255,  "can not ",  KC_A, KC_C, KC_N)
# SUBS(COMBO0256,  "under",  KC_BSPC, KC_D, KC_U)
# SUBS(COMBO0257,  "inter",  KC_BSPC, KC_I, KC_R)
# SUBS(COMBO0258,  "well ",  KC_BSPC, KC_L, KC_W)
# SUBS(COMBO0259,  "nding ",  KC_BSPC, KC_G, KC_N)
# SUBS(COMBO0260,  "ement",  KC_BSPC, KC_E, KC_M)
# SUBS(COMBO0261,  "and then ",  KC_A, KC_D, KC_N)
# SUBS(COMBO0262,  "nted ",  KC_D, KC_E, KC_N)
# SUBS(COMBO0263,  "pres",  KC_BSPC, KC_P, KC_R)
# SUBS(COMBO0264,  "was a ",  KC_BSPC, KC_S, KC_W)
# SUBS(COMBO0265,  "ied ",  KC_SPC, KC_E, KC_I)
# SUBS(COMBO0266,  "ition",  KC_BSPC, KC_I, KC_O)
# SUBS(COMBO0267,  "ings ",  KC_G, KC_I, KC_S)
# SUBS(COMBO0268,  "tly ",  KC_BSPC, KC_L, KC_T)
# SUBS(COMBO0269,  "cont",  KC_BSPC, KC_C, KC_O)
# SUBS(COMBO0270,  "ement ",  KC_SPC, KC_E, KC_M)
# SUBS(COMBO0271,  "hand",  KC_A, KC_D, KC_H)
# SUBS(COMBO0272,  "comp",  KC_C, KC_P)
# SUBS(COMBO0273,  "anything ",  KC_A, KC_G, KC_Y)
# SUBS(COMBO0274,  "and I ",  KC_A, KC_D, KC_I)
# SUBS(COMBO0275,  "I was ",  KC_I, KC_S, KC_W)
# SUBS(COMBO0276,  "different ",  KC_SPC, KC_D, KC_F)
# SUBS(COMBO0277,  "aking ",  KC_BSPC, KC_A, KC_K)
# SUBS(COMBO0278,  "age ",  KC_SPC, KC_E, KC_G)
# SUBS(COMBO0279,  "nothing ",  KC_G, KC_I, KC_N)
# SUBS(COMBO0280,  "stan",  KC_A, KC_N, KC_S)
# SUBS(COMBO0281,  "new ",  KC_E, KC_N, KC_W)
# SUBS(COMBO0282,  "would not ",  KC_N, KC_U, KC_W)
# SUBS(COMBO0283,  "for a ",  KC_BSPC, KC_F, KC_R)
# SUBS(COMBO0284,  "himself ",  KC_SPC, KC_F, KC_H)
# SUBS(COMBO0285,  "of a ",  KC_SPC, KC_A, KC_O)
# SUBS(COMBO0286,  "while ",  KC_I, KC_L, KC_W)
# SUBS(COMBO0287,  "everything ",  KC_BSPC, KC_E, KC_G)
# SUBS(COMBO0288,  "that he ",  KC_E, KC_H, KC_T)
# SUBS(COMBO0289,  "ped ",  KC_SPC, KC_E, KC_P)
# SUBS(COMBO0290,  "head ",  KC_D, KC_E, KC_H)
# SUBS(COMBO0291,  "in his ",  KC_BSPC, KC_H, KC_I)
# SUBS(COMBO0292,  "ration",  KC_I, KC_N, KC_R)
# SUBS(COMBO0293,  "nds ",  KC_D, KC_N, KC_S)
# SUBS(COMBO0294,  "he said ",  KC_D, KC_H, KC_S)
# SUBS(COMBO0295,  "one of ",  KC_BSPC, KC_F, KC_O)
# SUBS(COMBO0296,  "want",  KC_A, KC_N, KC_W)
# SUBS(COMBO0297,  "ress",  KC_BSPC, KC_R, KC_S)
# SUBS(COMBO0298,  "asked ",  KC_A, KC_D, KC_K)
# SUBS(COMBO0299,  "as the ",  KC_A, KC_E, KC_T)
# SUBS(COMBO0300,  "made ",  KC_SPC, KC_D, KC_M)
# SUBS(COMBO0301,  "being ",  KC_SPC, KC_B, KC_I)
# SUBS(COMBO0302,  "ration ",  KC_SPC, KC_I, KC_R)
# SUBS(COMBO0303,  "rning ",  KC_SPC, KC_N, KC_R)
# SUBS(COMBO0304,  "would have ",  KC_V, KC_W)
# SUBS(COMBO0305,  "information ",  KC_SPC, KC_F, KC_I)
# SUBS(COMBO0306,  "understand",  KC_BSPC, KC_N, KC_U)
# SUBS(COMBO0307,  "nation",  KC_A, KC_N, KC_O)
# SUBS(COMBO0308,  "ine ",  KC_E, KC_I, KC_N)
# SUBS(COMBO0309,  "of her ",  KC_F, KC_H, KC_O)
# SUBS(COMBO0310,  "those ",  KC_O, KC_S, KC_T)
# SUBS(COMBO0311,  "was the ",  KC_S, KC_T, KC_W)
# SUBS(COMBO0312,  "ition ",  KC_I, KC_O, KC_T)
# SUBS(COMBO0313,  "all the ",  KC_A, KC_L, KC_T)
# SUBS(COMBO0314,  "eyes ",  KC_SPC, KC_S, KC_Y)
# SUBS(COMBO0315,  "enti",  KC_E, KC_I, KC_T)
# SUBS(COMBO0316,  "about the ",  KC_A, KC_T, KC_U)
# SUBS(COMBO0317,  "ays ",  KC_A, KC_S, KC_Y)
# SUBS(COMBO0318,  "pped ",  KC_BSPC, KC_E, KC_P)
# SUBS(COMBO0319,  "want to ",  KC_N, KC_T, KC_W)
# SUBS(COMBO0320,  "he could ",  KC_SPC, KC_C, KC_H)
# SUBS(COMBO0321,  "night ",  KC_BSPC, KC_G, KC_H)
# SUBS(COMBO0322,  "together ",  KC_H, KC_R, KC_T)
# SUBS(COMBO0323,  "work",  KC_BSPC, KC_K, KC_W)
# SUBS(COMBO0324,  "much ",  KC_BSPC, KC_C, KC_M)
# SUBS(COMBO0325,  "cation",  KC_BSPC, KC_C, KC_T)
# SUBS(COMBO0326,  "has ",  KC_A, KC_H, KC_S)
# SUBS(COMBO0327,  "ched ",  KC_SPC, KC_C, KC_D)
# SUBS(COMBO0328,  "one of the ",  KC_F, KC_O, KC_T)
# SUBS(COMBO0329,  "place",  KC_BSPC, KC_C, KC_P)
# SUBS(COMBO0330,  "ined ",  KC_D, KC_E, KC_I)
# SUBS(COMBO0331,  "might ",  KC_SPC, KC_G, KC_M)
# SUBS(COMBO0332,  "sure ",  KC_SPC, KC_R, KC_S)
# SUBS(COMBO0333,  "question",  KC_O, KC_Q)
# SUBS(COMBO0334,  "light",  KC_G, KC_I, KC_L)
# SUBS(COMBO0335,  "also ",  KC_BSPC, KC_A, KC_L)
# SUBS(COMBO0336,  "ears ",  KC_E, KC_R, KC_S)
# SUBS(COMBO0337,  "port",  KC_BSPC, KC_O, KC_P)
# SUBS(COMBO0338,  "lation",  KC_A, KC_I, KC_L)
# SUBS(COMBO0339,  "ssion ",  KC_BSPC, KC_O, KC_S)
# SUBS(COMBO0340,  "face ",  KC_SPC, KC_E, KC_F)
# SUBS(COMBO0341,  "she could ",  KC_BSPC, KC_C, KC_U)
# SUBS(COMBO0342,  "things ",  KC_N, KC_S, KC_T)
# SUBS(COMBO0343,  "used ",  KC_D, KC_S, KC_U)
# SUBS(COMBO0344,  "have to ",  KC_SPC, KC_H, KC_V)
# SUBS(COMBO0345,  "ater ",  KC_A, KC_E, KC_R)
# SUBS(COMBO0346,  "a little ",  KC_A, KC_E, KC_L)
# SUBS(COMBO0347,  "each",  KC_C, KC_E, KC_H)
# SUBS(COMBO0348,  "not know ",  KC_BSPC, KC_K, KC_T)
# SUBS(COMBO0349,  "father ",  KC_BSPC, KC_F, KC_H)
# SUBS(COMBO0350,  "always ",  KC_A, KC_W, KC_Y)
# SUBS(COMBO0351,  "ange",  KC_A, KC_G, KC_N)
# SUBS(COMBO0352,  "I have ",  KC_H, KC_I, KC_V)
# SUBS(COMBO0353,  "the door ",  KC_BSPC, KC_D, KC_R)
# SUBS(COMBO0354,  "came ",  KC_A, KC_C, KC_M)
# SUBS(COMBO0355,  "take ",  KC_A, KC_K, KC_T)
# SUBS(COMBO0356,  "such ",  KC_BSPC, KC_C, KC_H)
# SUBS(COMBO0357,  "ational ",  KC_BSPC, KC_A, KC_O)
# SUBS(COMBO0358,  "is not ",  KC_I, KC_N, KC_S)
# SUBS(COMBO0359,  "wanted ",  KC_BSPC, KC_D, KC_W)
# SUBS(COMBO0360,  "present",  KC_BSPC, KC_P, KC_S)
# SUBS(COMBO0361,  "nder ",  KC_D, KC_N, KC_R)
# SUBS(COMBO0362,  "she said ",  KC_H, KC_I, KC_S)
# SUBS(COMBO0363,  "press",  KC_P, KC_R, KC_S)
# SUBS(COMBO0364,  "make ",  KC_SPC, KC_E, KC_K)
# SUBS(COMBO0365,  "looking ",  KC_SPC, KC_G, KC_K)
# SUBS(COMBO0366,  "mother ",  KC_BSPC, KC_M, KC_R)
# SUBS(COMBO0367,  "ous ",  KC_O, KC_S, KC_U)
# SUBS(COMBO0368,  "does not ",  KC_D, KC_N, KC_O)
# SUBS(COMBO0369,  "really ",  KC_SPC, KC_R, KC_Y)
# SUBS(COMBO0370,  "table ",  KC_SPC, KC_B, KC_L)
# SUBS(COMBO0371,  "each ",  KC_A, KC_C, KC_E)
# SUBS(COMBO0372,  "more than ",  KC_M, KC_R, KC_T)
# SUBS(COMBO0373,  "ments ",  KC_E, KC_M, KC_S)
# SUBS(COMBO0374,  "ral ",  KC_SPC, KC_L, KC_R)
# SUBS(COMBO0375,  "over the ",  KC_SPC, KC_R, KC_V)
# SUBS(COMBO0376,  "day ",  KC_SPC, KC_D, KC_Y)
# SUBS(COMBO0377,  "that was ",  KC_H, KC_T, KC_W)
# SUBS(COMBO0378,  "owing ",  KC_G, KC_W)
# SUBS(COMBO0379,  "cation ",  KC_SPC, KC_C, KC_O)
# SUBS(COMBO0380,  "two ",  KC_O, KC_T, KC_W)
# SUBS(COMBO0381,  "place ",  KC_SPC, KC_C, KC_P)
# SUBS(COMBO0382,  "read",  KC_D, KC_E, KC_R)
# SUBS(COMBO0383,  "away ",  KC_BSPC, KC_W, KC_Y)
# SUBS(COMBO0384,  "ared ",  KC_A, KC_D, KC_E)
# SUBS(COMBO0385,  "room ",  KC_M, KC_O, KC_R)
# SUBS(COMBO0386,  "ness ",  KC_E, KC_N, KC_S)
# SUBS(COMBO0387,  "shed ",  KC_E, KC_H, KC_S)
# SUBS(COMBO0388,  "and he ",  KC_A, KC_E, KC_H)
# SUBS(COMBO0389,  "mber ",  KC_SPC, KC_B, KC_M)
# SUBS(COMBO0390,  "life ",  KC_SPC, KC_F, KC_L)
# SUBS(COMBO0391,  "cons",  KC_C, KC_N, KC_O)
# SUBS(COMBO0392,  "follow",  KC_BSPC, KC_F, KC_W)
# SUBS(COMBO0393,  "children ",  KC_BSPC, KC_C, KC_L)
# SUBS(COMBO0394,  "wanted to ",  KC_D, KC_N, KC_W)
# SUBS(COMBO0395,  "enough ",  KC_BSPC, KC_E, KC_O)
# SUBS(COMBO0396,  "this is ",  KC_H, KC_I, KC_T)
# SUBS(COMBO0397,  "ove ",  KC_E, KC_O, KC_V)
# SUBS(COMBO0398,  "to her ",  KC_BSPC, KC_H, KC_R)
# SUBS(COMBO0399,  "ried ",  KC_D, KC_I, KC_R)
# SUBS(COMBO0400,  "work ",  KC_SPC, KC_K, KC_R)
# SUBS(COMBO0401,  "hear",  KC_E, KC_H, KC_R)
# SUBS(COMBO0402,  "not have ",  KC_BSPC, KC_H, KC_V)
# SUBS(COMBO0403,  "change",  KC_C, KC_G)
# SUBS(COMBO0404,  "years ",  KC_BSPC, KC_R, KC_Y)
# SUBS(COMBO0405,  "count",  KC_C, KC_N, KC_U)
# SUBS(COMBO0406,  "is the ",  KC_E, KC_I, KC_S)
# SUBS(COMBO0407,  "cted ",  KC_BSPC, KC_C, KC_D)
# SUBS(COMBO0408,  "tation ",  KC_A, KC_I, KC_T)
# SUBS(COMBO0409,  "call",  KC_A, KC_C, KC_L)
# SUBS(COMBO0410,  "med ",  KC_BSPC, KC_D, KC_M)
# SUBS(COMBO0411,  "there is ",  KC_I, KC_R, KC_T)
# SUBS(COMBO0412,  "however ",  KC_SPC, KC_V, KC_W)
# SUBS(COMBO0413,  "out of the ",  KC_O, KC_T, KC_U)
# SUBS(COMBO0414,  "ected ",  KC_C, KC_D, KC_E)
# SUBS(COMBO0415,  "I could ",  KC_SPC, KC_I, KC_U)
# SUBS(COMBO0416,  "that she ",  KC_A, KC_E, KC_S)
# SUBS(COMBO0417,  "friend",  KC_BSPC, KC_F, KC_I)
# SUBS(COMBO0418,  "house ",  KC_SPC, KC_H, KC_U)
# SUBS(COMBO0419,  "under ",  KC_D, KC_R, KC_U)
# SUBS(COMBO0420,  "found ",  KC_SPC, KC_F, KC_U)
# SUBS(COMBO0421,  "ready ",  KC_D, KC_R, KC_Y)
# SUBS(COMBO0422,  "light ",  KC_G, KC_H, KC_I)
# SUBS(COMBO0423,  "ious ",  KC_BSPC, KC_I, KC_U)
# SUBS(COMBO0424,  "had not ",  KC_D, KC_H, KC_O)
# SUBS(COMBO0425,  "you have ",  KC_SPC, KC_H, KC_Y)
# SUBS(COMBO0426,  "if you ",  KC_SPC, KC_F, KC_Y)
# SUBS(COMBO0427,  "consider",  KC_BSPC, KC_C, KC_R)
# SUBS(COMBO0428,  "member",  KC_BSPC, KC_B, KC_M)
# SUBS(COMBO0429,  "spec",  KC_E, KC_P, KC_S)
# SUBS(COMBO0430,  "of course ",  KC_C, KC_O, KC_U)
# SUBS(COMBO0431,  "to get ",  KC_E, KC_G, KC_O)
# SUBS(COMBO0432,  "acti",  KC_A, KC_C, KC_I)
# SUBS(COMBO0433,  "you know ",  KC_SPC, KC_K, KC_Y)
# SUBS(COMBO0434,  "national ",  KC_N, KC_O, KC_T)
# SUBS(COMBO0435,  "back to ",  KC_SPC, KC_B, KC_K)
# SUBS(COMBO0436,  "possible ",  KC_SPC, KC_L, KC_P)
# SUBS(COMBO0437,  "world ",  KC_D, KC_L, KC_W)
# SUBS(COMBO0438,  "ering ",  KC_E, KC_G, KC_R)
# SUBS(COMBO0439,  "already ",  KC_SPC, KC_L, KC_Y)
# SUBS(COMBO0440,  "and she ",  KC_A, KC_E, KC_N)
# SUBS(COMBO0441,  "to make ",  KC_A, KC_M, KC_T)
# SUBS(COMBO0442,  "called ",  KC_C, KC_D, KC_L)
# SUBS(COMBO0443,  "comm",  KC_C, KC_M, KC_O)
# SUBS(COMBO0444,  "ication",  KC_C, KC_I, KC_N)
# SUBS(COMBO0445,  "better ",  KC_SPC, KC_B, KC_R)
# SUBS(COMBO0446,  "person",  KC_BSPC, KC_N, KC_P)
# SUBS(COMBO0447,  "understand ",  KC_BSPC, KC_A, KC_U)
# SUBS(COMBO0448,  "every ",  KC_E, KC_V, KC_Y)
# SUBS(COMBO0449,  "ually ",  KC_BSPC, KC_U, KC_Y)
# SUBS(COMBO0450,  "lity ",  KC_BSPC, KC_L, KC_Y)
# SUBS(COMBO0451,  "behind ",  KC_BSPC, KC_B, KC_I)
# SUBS(COMBO0452,  "moment ",  KC_M, KC_O, KC_T)
# SUBS(COMBO0453,  "do not know ",  KC_BSPC, KC_D, KC_K)
# SUBS(COMBO0454,  "he did not ",  KC_D, KC_H, KC_I)
# SUBS(COMBO0455,  "many ",  KC_SPC, KC_M, KC_Y)
# SUBS(COMBO0456,  "I did not ",  KC_D, KC_I, KC_O)
# SUBS(COMBO0457,  "the world ",  KC_L, KC_T, KC_W)
# SUBS(COMBO0458,  "you can ",  KC_SPC, KC_C, KC_Y)
# SUBS(COMBO0459,  "remember",  KC_BSPC, KC_B, KC_R)
# SUBS(COMBO0460,  "to have ",  KC_H, KC_O, KC_T)
# SUBS(COMBO0461,  "ary ",  KC_A, KC_R, KC_Y)
# SUBS(COMBO0462,  "interest",  KC_I, KC_R, KC_S)
# SUBS(COMBO0463,  "when he ",  KC_E, KC_H, KC_W)
# SUBS(COMBO0464,  "standing ",  KC_G, KC_N, KC_S)
# SUBS(COMBO0465,  "important ",  KC_SPC, KC_I, KC_P)
# SUBS(COMBO0466,  "close",  KC_C, KC_L, KC_O)
# SUBS(COMBO0467,  "herself ",  KC_BSPC, KC_F, KC_L)
# SUBS(COMBO0468,  "star",  KC_R, KC_S, KC_T)
# SUBS(COMBO0469,  "experience",  KC_BSPC, KC_E, KC_X)
# SUBS(COMBO0470,  "ention",  KC_E, KC_N, KC_T)
# SUBS(COMBO0471,  "ves ",  KC_SPC, KC_S, KC_V)
# SUBS(COMBO0472,  "against the ",  KC_A, KC_G, KC_I)
# SUBS(COMBO0473,  "to see ",  KC_E, KC_O, KC_S)
# SUBS(COMBO0474,  "ently ",  KC_E, KC_L, KC_Y)
# SUBS(COMBO0475,  "of this ",  KC_F, KC_I, KC_T)
# SUBS(COMBO0476,  "in her ",  KC_H, KC_I, KC_R)
# SUBS(COMBO0477,  "late",  KC_E, KC_L, KC_T)
# SUBS(COMBO0478,  "will not ",  KC_I, KC_N, KC_W)
# SUBS(COMBO0479,  "he would ",  KC_H, KC_U, KC_W)
# SUBS(COMBO0480,  "will be ",  KC_B, KC_L, KC_W)
# SUBS(COMBO0481,  "air ",  KC_A, KC_I, KC_R)
# SUBS(COMBO0482,  "family ",  KC_BSPC, KC_F, KC_Y)
# SUBS(COMBO0483,  "seemed ",  KC_D, KC_M, KC_S)
# SUBS(COMBO0484,  "university ",  KC_SPC, KC_U, KC_V)
# SUBS(COMBO0485,  "cial ",  KC_C, KC_I, KC_L)
# SUBS(COMBO0486,  "low ",  KC_L, KC_O, KC_W)
# SUBS(COMBO0487,  "point",  KC_BSPC, KC_I, KC_P)
# SUBS(COMBO0488,  "trying to ",  KC_R, KC_T, KC_Y)
# SUBS(COMBO0489,  "toward",  KC_D, KC_O, KC_W)
# SUBS(COMBO0490,  "ming ",  KC_BSPC, KC_G, KC_M)
# SUBS(COMBO0491,  "that I ",  KC_A, KC_H, KC_I)
# SUBS(COMBO0492,  "mple",  KC_BSPC, KC_M, KC_P)
# SUBS(COMBO0493,  "do you ",  KC_BSPC, KC_D, KC_Y)
# SUBS(COMBO0494,  "cked ",  KC_SPC, KC_C, KC_K)
# SUBS(COMBO0495,  "must ",  KC_SPC, KC_M, KC_U)
# SUBS(COMBO0496,  "develop",  KC_BSPC, KC_L, KC_V)
# SUBS(COMBO0497,  "once",  KC_C, KC_E, KC_O)
# SUBS(COMBO0498,  "with her ",  KC_H, KC_I, KC_W)
# SUBS(COMBO0499,  "believe",  KC_BSPC, KC_B, KC_L)
# SUBS(COMBO0500,  "someone ",  KC_M, KC_O, KC_S)
# SUBS(COMBO0501,  "great ",  KC_A, KC_E, KC_G)
# SUBS(COMBO0502,  "cent",  KC_C, KC_N, KC_T)
# SUBS(COMBO0503,  "you are ",  KC_A, KC_U, KC_Y)
# SUBS(COMBO0504,  "ctions ",  KC_SPC, KC_C, KC_T)
# SUBS(COMBO0505,  "knew ",  KC_BSPC, KC_E, KC_K)
# SUBS(COMBO0506,  "of them ",  KC_F, KC_M, KC_T)
# SUBS(COMBO0507,  "nger",  KC_G, KC_N, KC_R)
# SUBS(COMBO0508,  "not be ",  KC_BSPC, KC_B, KC_N)
# SUBS(COMBO0509,  "the time ",  KC_SPC, KC_I, KC_M)
# SUBS(COMBO0510,  "until ",  KC_SPC, KC_L, KC_U)
# SUBS(COMBO0511,  "when the ",  KC_E, KC_T, KC_W)
# SUBS(COMBO0512,  "ping ",  KC_SPC, KC_N, KC_P)
# SUBS(COMBO0513,  "the way ",  KC_H, KC_W, KC_Y)
# SUBS(COMBO0514,  "both ",  KC_BSPC, KC_B, KC_O)
# SUBS(COMBO0515,  "ession",  KC_I, KC_O, KC_S)
# SUBS(COMBO0516,  "continu",  KC_C, KC_I, KC_U)
# SUBS(COMBO0517,  "eral ",  KC_E, KC_L, KC_R)
# SUBS(COMBO0518,  "body ",  KC_BSPC, KC_B, KC_Y)
# SUBS(COMBO0519,  "took ",  KC_K, KC_O, KC_T)
# SUBS(COMBO0520,  "his head ",  KC_E, KC_H, KC_I)
# SUBS(COMBO0521,  "etting ",  KC_E, KC_G, KC_I)
# SUBS(COMBO0522,  "business ",  KC_SPC, KC_B, KC_U)
# SUBS(COMBO0523,  "early ",  KC_E, KC_R, KC_Y)
# SUBS(COMBO0524,  "nger ",  KC_E, KC_G, KC_N)
# SUBS(COMBO0525,  "bility ",  KC_B, KC_L, KC_Y)
# SUBS(COMBO0526,  "particular",  KC_BSPC, KC_P, KC_U)
# SUBS(COMBO0527,  "but the ",  KC_BSPC, KC_B, KC_U)
# SUBS(COMBO0528,  "but I ",  KC_B, KC_I, KC_U)
# SUBS(COMBO0529,  "times ",  KC_I, KC_M, KC_T)
# SUBS(COMBO0530,  "left ",  KC_F, KC_L, KC_T)
# SUBS(COMBO0531,  "I do not know ",  KC_SPC, KC_I, KC_K)
# SUBS(COMBO0532,  "ained ",  KC_A, KC_E, KC_I)
# SUBS(COMBO0533,  "development",  KC_M, KC_V)
# SUBS(COMBO0534,  "certain",  KC_C, KC_I, KC_R)
# SUBS(COMBO0535,  "woman ",  KC_M, KC_W)
# SUBS(COMBO0536,  "it would ",  KC_I, KC_U, KC_W)
# SUBS(COMBO0537,  "rds ",  KC_D, KC_R, KC_S)
# SUBS(COMBO0538,  "like a ",  KC_A, KC_I, KC_K)
# SUBS(COMBO0539,  "to his ",  KC_H, KC_O, KC_S)
# SUBS(COMBO0540,  "others ",  KC_O, KC_R, KC_S)
# SUBS(COMBO0541,  "she did not ",  KC_D, KC_O, KC_S)
# SUBS(COMBO0542,  "the most ",  KC_E, KC_M, KC_T)
# SUBS(COMBO0543,  "cross ",  KC_SPC, KC_C, KC_R)
# SUBS(COMBO0544,  "relation",  KC_BSPC, KC_L, KC_R)
# SUBS(COMBO0545,  "either ",  KC_E, KC_I, KC_R)
# SUBS(COMBO0546,  "pened ",  KC_E, KC_N, KC_P)
# SUBS(COMBO0547,  "action",  KC_A, KC_C, KC_O)
# SUBS(COMBO0548,  "with his ",  KC_H, KC_S, KC_W)
# SUBS(COMBO0549,  "there were ",  KC_BSPC, KC_E, KC_W)
# SUBS(COMBO0550,  "contr",  KC_C, KC_N, KC_R)
# SUBS(COMBO0551,  "since ",  KC_C, KC_E, KC_I)
# SUBS(COMBO0552,  "almost ",  KC_A, KC_M, KC_S)
# SUBS(COMBO0553,  "across ",  KC_A, KC_O, KC_R)
# SUBS(COMBO0554,  "development ",  KC_SPC, KC_M, KC_V)
# SUBS(COMBO0555,  "ention ",  KC_E, KC_O, KC_T)
# SUBS(COMBO0556,  "at least ",  KC_A, KC_L, KC_S)
# SUBS(COMBO0557,  "speci",  KC_I, KC_P, KC_S)
# SUBS(COMBO0558,  "appear",  KC_A, KC_E, KC_P)
# SUBS(COMBO0559,  "son ",  KC_N, KC_O, KC_S)
# SUBS(COMBO0560,  "last ",  KC_L, KC_S, KC_T)
# SUBS(COMBO0561,  "second",  KC_C, KC_D, KC_N)
# SUBS(COMBO0562,  "ching ",  KC_SPC, KC_C, KC_G)
# SUBS(COMBO0563,  "voice ",  KC_C, KC_V)
# SUBS(COMBO0564,  "across the ",  KC_C, KC_R, KC_T)
# SUBS(COMBO0565,  "following ",  KC_SPC, KC_F, KC_G)
# SUBS(COMBO0566,  "relationship",  KC_L, KC_P, KC_R)
# SUBS(COMBO0567,  "continue",  KC_C, KC_T, KC_U)
# SUBS(COMBO0568,  "ory ",  KC_O, KC_R, KC_Y)
# SUBS(COMBO0569,  "direct",  KC_C, KC_D, KC_R)
# SUBS(COMBO0570,  "are you ",  KC_A, KC_O, KC_Y)
# SUBS(COMBO0571,  "happen",  KC_BSPC, KC_H, KC_P)
# SUBS(COMBO0572,  "tely ",  KC_L, KC_T, KC_Y)
# SUBS(COMBO0573,  "tory ",  KC_O, KC_T, KC_Y)
# SUBS(COMBO0574,  "position",  KC_N, KC_P, KC_S)
# SUBS(COMBO0575,  "morning ",  KC_BSPC, KC_I, KC_M)
# SUBS(COMBO0576,  "produc",  KC_C, KC_P, KC_U)
# SUBS(COMBO0577,  "serv",  KC_BSPC, KC_S, KC_V)
# SUBS(COMBO0578,  "not want ",  KC_N, KC_O, KC_W)
# SUBS(COMBO0579,  "ative ",  KC_SPC, KC_A, KC_V)
# SUBS(COMBO0580,  "lation ",  KC_A, KC_L, KC_O)
# SUBS(COMBO0581,  "ication ",  KC_C, KC_I, KC_O)
# SUBS(COMBO0582,  "genera",  KC_A, KC_N, KC_R)
# SUBS(COMBO0583,  "iving ",  KC_I, KC_N, KC_V)
# SUBS(COMBO0584,  "question ",  KC_Q, KC_T)
# SUBS(COMBO0585,  "aring ",  KC_G, KC_I, KC_R)
# SUBS(COMBO0586,  "ctive ",  KC_SPC, KC_C, KC_V)
# SUBS(COMBO0587,  "told ",  KC_L, KC_O, KC_T)
# SUBS(COMBO0588,  "second ",  KC_C, KC_D, KC_O)
# SUBS(COMBO0589,  "that they ",  KC_H, KC_T, KC_Y)
# SUBS(COMBO0590,  "should be ",  KC_SPC, KC_B, KC_S)
# SUBS(COMBO0591,  "ember ",  KC_SPC, KC_B, KC_E)
# SUBS(COMBO0592,  "of their ",  KC_F, KC_O, KC_R)
# SUBS(COMBO0593,  "system",  KC_BSPC, KC_S, KC_Y)
# SUBS(COMBO0594,  "give",  KC_E, KC_I, KC_V)
# SUBS(COMBO0595,  "had to ",  KC_A, KC_O, KC_T)
# SUBS(COMBO0596,  "coming ",  KC_BSPC, KC_C, KC_G)
# SUBS(COMBO0597,  "international ",  KC_I, KC_L, KC_R)
# SUBS(COMBO0598,  "uring ",  KC_G, KC_R, KC_U)
# SUBS(COMBO0599,  "has been ",  KC_B, KC_H, KC_S)
# SUBS(COMBO0600,  "during ",  KC_D, KC_I, KC_U)
# SUBS(COMBO0601,  "need to ",  KC_D, KC_E, KC_O)
# SUBS(COMBO0602,  "owed ",  KC_E, KC_O, KC_W)
# SUBS(COMBO0603,  "may ",  KC_BSPC, KC_M, KC_Y)
# SUBS(COMBO0604,  "although ",  KC_A, KC_G, KC_U)
# SUBS(COMBO0605,  "government",  KC_BSPC, KC_M, KC_V)
# SUBS(COMBO0606,  "between the ",  KC_B, KC_N, KC_W)
# SUBS(COMBO0607,  "respon",  KC_N, KC_P, KC_R)
# SUBS(COMBO0608,  "I think ",  KC_I, KC_K, KC_T)
# SUBS(COMBO0609,  "looked at ",  KC_A, KC_D, KC_L)
# SUBS(COMBO0610,  "they had ",  KC_BSPC, KC_H, KC_Y)
# SUBS(COMBO0611,  "they are ",  KC_A, KC_T, KC_Y)
# SUBS(COMBO0612,  "part ",  KC_SPC, KC_P, KC_R)
# SUBS(COMBO0613,  "felt ",  KC_BSPC, KC_E, KC_F)
# SUBS(COMBO0614,  "believe ",  KC_SPC, KC_L, KC_V)
# SUBS(COMBO0615,  "and his ",  KC_A, KC_I, KC_S)
# SUBS(COMBO0616,  "llowed ",  KC_E, KC_L, KC_W)
# SUBS(COMBO0617,  "a few ",  KC_SPC, KC_F, KC_W)
# SUBS(COMBO0618,  "have a ",  KC_A, KC_H, KC_V)
# SUBS(COMBO0619,  "position ",  KC_SPC, KC_P, KC_S)
# SUBS(COMBO0620,  "his eyes ",  KC_E, KC_H, KC_Y)
# SUBS(COMBO0621,  "around the ",  KC_A, KC_D, KC_U)
# SUBS(COMBO0622,  "government ",  KC_BSPC, KC_R, KC_V)
# SUBS(COMBO0623,  "mean",  KC_A, KC_E, KC_M)
# SUBS(COMBO0624,  "water ",  KC_A, KC_E, KC_W)
# SUBS(COMBO0625,  "struct",  KC_R, KC_S, KC_U)
# SUBS(COMBO0626,  "can be ",  KC_SPC, KC_B, KC_C)
# SUBS(COMBO0627,  "special",  KC_L, KC_P, KC_S)
# SUBS(COMBO0628,  "when she ",  KC_N, KC_S, KC_W)
# SUBS(COMBO0629,  "probably ",  KC_SPC, KC_P, KC_Y)
# SUBS(COMBO0630,  "action ",  KC_A, KC_I, KC_O)
# SUBS(COMBO0631,  "change ",  KC_C, KC_G, KC_N)
# SUBS(COMBO0632,  "part of ",  KC_SPC, KC_O, KC_P)
# SUBS(COMBO0633,  "shoulder",  KC_L, KC_S, KC_U)
# SUBS(COMBO0634,  "in front of ",  KC_F, KC_I, KC_O)
# SUBS(COMBO0635,  "as well ",  KC_A, KC_L, KC_W)
# SUBS(COMBO0636,  "tance ",  KC_C, KC_E, KC_T)
# SUBS(COMBO0637,  "tical ",  KC_C, KC_L, KC_T)
# SUBS(COMBO0638,  "pect",  KC_C, KC_E, KC_P)
# SUBS(COMBO0639,  "the house ",  KC_H, KC_T, KC_U)
# SUBS(COMBO0640,  "compa",  KC_C, KC_M, KC_P)
# SUBS(COMBO0641,  "each other ",  KC_E, KC_O, KC_R)
# SUBS(COMBO0642,  "compl",  KC_C, KC_L, KC_P)
# SUBS(COMBO0643,  "I can not ",  KC_C, KC_I, KC_T)
# SUBS(COMBO0644,  "the room ",  KC_H, KC_O, KC_R)
# SUBS(COMBO0645,  "within ",  KC_I, KC_T, KC_W)
# SUBS(COMBO0646,  "having ",  KC_A, KC_G, KC_H)
# SUBS(COMBO0647,  "ful ",  KC_BSPC, KC_F, KC_U)
# SUBS(COMBO0648,  "happened ",  KC_SPC, KC_H, KC_P)
# SUBS(COMBO0649,  "away from ",  KC_A, KC_F, KC_Y)
# SUBS(COMBO0650,  "she would ",  KC_S, KC_U, KC_W)
# SUBS(COMBO0651,  "you do not ",  KC_SPC, KC_N, KC_Y)
# SUBS(COMBO0652,  "general",  KC_G, KC_L, KC_R)
# SUBS(COMBO0653,  "ature ",  KC_A, KC_R, KC_U)
# SUBS(COMBO0654,  "not want to ",  KC_A, KC_O, KC_W)
# SUBS(COMBO0655,  "that you ",  KC_T, KC_U, KC_Y)
# SUBS(COMBO0656,  "thinking ",  KC_BSPC, KC_G, KC_K)
# SUBS(COMBO0657,  "story ",  KC_R, KC_S, KC_Y)
# SUBS(COMBO0658,  "ference",  KC_BSPC, KC_F, KC_N)
# SUBS(COMBO0659,  "answer",  KC_N, KC_R, KC_S)
# SUBS(COMBO0660,  "control",  KC_C, KC_L, KC_R)
# SUBS(COMBO0661,  "themselves ",  KC_M, KC_S, KC_V)
# SUBS(COMBO0662,  "ective",  KC_C, KC_E, KC_V)
# SUBS(COMBO0663,  "there was a ",  KC_A, KC_H, KC_W)
# SUBS(COMBO0664,  "love",  KC_L, KC_O, KC_V)
# SUBS(COMBO0665,  "problem",  KC_BSPC, KC_L, KC_P)
# SUBS(COMBO0666,  "able to ",  KC_A, KC_B, KC_L)
# SUBS(COMBO0667,  "america",  KC_A, KC_M, KC_R)
# SUBS(COMBO0668,  "process",  KC_C, KC_P, KC_R)
# SUBS(COMBO0669,  "stance",  KC_C, KC_E, KC_N)
# SUBS(COMBO0670,  "search",  KC_H, KC_R, KC_S)
# SUBS(COMBO0671,  "to take ",  KC_E, KC_K, KC_T)
# SUBS(COMBO0672,  "heard ",  KC_D, KC_H, KC_R)
# SUBS(COMBO0673,  "remember ",  KC_B, KC_M, KC_R)
# SUBS(COMBO0674,  "her eyes ",  KC_H, KC_R, KC_Y)
# SUBS(COMBO0675,  "return",  KC_N, KC_R, KC_U)
# SUBS(COMBO0676,  "down the ",  KC_D, KC_H, KC_W)
# SUBS(COMBO0677,  "perhaps ",  KC_SPC, KC_A, KC_P)
# SUBS(COMBO0678,  "uction ",  KC_I, KC_N, KC_U)
# SUBS(COMBO0679,  "making ",  KC_BSPC, KC_I, KC_K)
# SUBS(COMBO0680,  "lear",  KC_A, KC_L, KC_R)
# SUBS(COMBO0681,  "individual",  KC_I, KC_U, KC_V)
# SUBS(COMBO0682,  "several ",  KC_L, KC_S, KC_V)
# SUBS(COMBO0683,  "everyone ",  KC_BSPC, KC_V, KC_Y)
# SUBS(COMBO0684,  "seemed to ",  KC_D, KC_M, KC_O)
# SUBS(COMBO0685,  "pression ",  KC_I, KC_P, KC_R)
# SUBS(COMBO0686,  "complete",  KC_C, KC_O, KC_P)
# SUBS(COMBO0687,  "but he ",  KC_B, KC_H, KC_U)
# SUBS(COMBO0688,  "find ",  KC_SPC, KC_F, KC_N)
# SUBS(COMBO0689,  "smile",  KC_I, KC_M, KC_S)
# SUBS(COMBO0690,  "augh",  KC_A, KC_H, KC_U)
# SUBS(COMBO0691,  "words ",  KC_D, KC_S, KC_W)
# SUBS(COMBO0692,  "I know ",  KC_I, KC_K, KC_W)
# SUBS(COMBO0693,  "toward ",  KC_D, KC_O, KC_R)
# SUBS(COMBO0694,  "aying ",  KC_A, KC_N, KC_Y)
# SUBS(COMBO0695,  "number ",  KC_B, KC_N, KC_U)
# SUBS(COMBO0696,  "especially ",  KC_E, KC_P, KC_Y)
# SUBS(COMBO0697,  "the next ",  KC_SPC, KC_N, KC_X)
# SUBS(COMBO0698,  "communi",  KC_C, KC_M, KC_U)
# SUBS(COMBO0699,  "opped ",  KC_E, KC_O, KC_P)
# SUBS(COMBO0700,  "continued ",  KC_C, KC_D, KC_U)
# SUBS(COMBO0701,  "feeling",  KC_BSPC, KC_F, KC_G)
# SUBS(COMBO0702,  "atch",  KC_A, KC_C, KC_H)
# SUBS(COMBO0703,  "the following ",  KC_F, KC_T, KC_W)
# SUBS(COMBO0704,  "research ",  KC_C, KC_H, KC_R)
# SUBS(COMBO0705,  "includ",  KC_I, KC_L, KC_U)
# SUBS(COMBO0706,  "fect",  KC_E, KC_F, KC_T)
# SUBS(COMBO0707,  "alking ",  KC_A, KC_G, KC_K)
# SUBS(COMBO0708,  "love ",  KC_E, KC_L, KC_V)
# SUBS(COMBO0709,  "office",  KC_E, KC_F, KC_O)
# SUBS(COMBO0710,  "sometimes ",  KC_E, KC_I, KC_M)
# SUBS(COMBO0711,  "it was not ",  KC_A, KC_I, KC_W)
# SUBS(COMBO0712,  "when I ",  KC_E, KC_I, KC_W)
# SUBS(COMBO0713,  "ution",  KC_I, KC_T, KC_U)
# SUBS(COMBO0714,  "under the ",  KC_N, KC_T, KC_U)
# SUBS(COMBO0715,  "experience ",  KC_SPC, KC_E, KC_X)
# SUBS(COMBO0716,  "provide",  KC_I, KC_R, KC_V)
# SUBS(COMBO0717,  "I thought ",  KC_G, KC_I, KC_U)
# SUBS(COMBO0718,  "cover",  KC_BSPC, KC_C, KC_V)
# SUBS(COMBO0719,  "attention ",  KC_A, KC_E, KC_O)
# SUBS(COMBO0720,  "nally ",  KC_BSPC, KC_N, KC_Y)
# SUBS(COMBO0721,  "finally ",  KC_F, KC_L, KC_Y)
# SUBS(COMBO0722,  "young ",  KC_G, KC_U, KC_Y)
# SUBS(COMBO0723,  "during the ",  KC_D, KC_N, KC_U)
# SUBS(COMBO0724,  "character",  KC_C, KC_H, KC_T)
# SUBS(COMBO0725,  "approach",  KC_A, KC_H, KC_P)
# SUBS(COMBO0726,  "system ",  KC_M, KC_S, KC_Y)
# SUBS(COMBO0727,  "I would ",  KC_D, KC_I, KC_W)
# SUBS(COMBO0728,  "school ",  KC_L, KC_O, KC_S)
# SUBS(COMBO0729,  "ective ",  KC_C, KC_I, KC_V)
# SUBS(COMBO0730,  "open",  KC_N, KC_O, KC_P)
# SUBS(COMBO0731,  "alked ",  KC_A, KC_E, KC_K)
# SUBS(COMBO0732,  "control ",  KC_C, KC_O, KC_R)
# SUBS(COMBO0733,  "number of ",  KC_B, KC_N, KC_O)
# SUBS(COMBO0734,  "friend ",  KC_D, KC_F, KC_R)
# SUBS(COMBO0735,  "brea",  KC_BSPC, KC_B, KC_E)
# SUBS(COMBO0736,  "mind ",  KC_D, KC_I, KC_M)
# SUBS(COMBO0737,  "brought ",  KC_B, KC_R, KC_U)
# SUBS(COMBO0738,  "reason",  KC_N, KC_O, KC_R)
# SUBS(COMBO0739,  "relationship ",  KC_H, KC_P, KC_R)
# SUBS(COMBO0740,  "the only ",  KC_N, KC_T, KC_Y)
# SUBS(COMBO0741,  "we have ",  KC_H, KC_V, KC_W)
# SUBS(COMBO0742,  "publi",  KC_L, KC_P, KC_U)
# SUBS(COMBO0743,  "the United States ",  KC_S, KC_T, KC_U)
# SUBS(COMBO0744,  "on her ",  KC_E, KC_N, KC_R)
# SUBS(COMBO0745,  "eration",  KC_I, KC_O, KC_R)
# SUBS(COMBO0746,  "ground ",  KC_G, KC_N, KC_U)
# SUBS(COMBO0747,  "ately ",  KC_A, KC_L, KC_Y)
# SUBS(COMBO0748,  "figure",  KC_F, KC_G, KC_U)
# SUBS(COMBO0749,  "suddenly ",  KC_S, KC_U, KC_Y)
# SUBS(COMBO0750,  "move",  KC_M, KC_O, KC_V)
# SUBS(COMBO0751,  "did not know ",  KC_D, KC_K, KC_W)
# SUBS(COMBO0752,  "general ",  KC_A, KC_G, KC_L)
# SUBS(COMBO0753,  "tually ",  KC_L, KC_T, KC_U)
# SUBS(COMBO0754,  "outside ",  KC_D, KC_O, KC_U)
# SUBS(COMBO0755,  "ual ",  KC_BSPC, KC_L, KC_U)
# SUBS(COMBO0756,  "could be ",  KC_BSPC, KC_B, KC_C)
# SUBS(COMBO0757,  "ability ",  KC_A, KC_B, KC_Y)
# SUBS(COMBO0758,  "help ",  KC_E, KC_H, KC_P)
# SUBS(COMBO0759,  "person ",  KC_O, KC_P, KC_R)
# SUBS(COMBO0760,  "appeared ",  KC_E, KC_P, KC_R)
# SUBS(COMBO0761,  "american",  KC_A, KC_I, KC_M)
# SUBS(COMBO0762,  "socia",  KC_A, KC_O, KC_S)
# SUBS(COMBO0763,  "as if ",  KC_A, KC_F, KC_I)
# SUBS(COMBO0764,  "as well as ",  KC_L, KC_S, KC_W)
# SUBS(COMBO0765,  "example",  KC_M, KC_X)
# SUBS(COMBO0766,  "walked ",  KC_A, KC_K, KC_W)
# SUBS(COMBO0767,  "outh ",  KC_BSPC, KC_H, KC_U)
# SUBS(COMBO0768,  "later ",  KC_L, KC_R, KC_T)
# SUBS(COMBO0769,  "according to ",  KC_C, KC_G, KC_R)
# SUBS(COMBO0770,  "example ",  KC_L, KC_X)
# SUBS(COMBO0771,  "such as ",  KC_A, KC_S, KC_U)
# SUBS(COMBO0772,  "respons",  KC_O, KC_P, KC_S)
# SUBS(COMBO0773,  "using ",  KC_G, KC_S, KC_U)
# SUBS(COMBO0774,  "increas",  KC_C, KC_E, KC_R)
# SUBS(COMBO0775,  "point ",  KC_I, KC_N, KC_P)
# SUBS(COMBO0776,  "condition",  KC_C, KC_D, KC_I)
# SUBS(COMBO0777,  "knowledge ",  KC_SPC, KC_G, KC_W)
# SUBS(COMBO0778,  "require",  KC_Q, KC_R)
# SUBS(COMBO0779,  "compan",  KC_C, KC_N, KC_P)
# SUBS(COMBO0780,  "maybe ",  KC_B, KC_M, KC_Y)
# SUBS(COMBO0781,  "ference ",  KC_F, KC_N, KC_R)
# SUBS(COMBO0782,  "watch",  KC_BSPC, KC_C, KC_W)
# SUBS(COMBO0783,  "and they ",  KC_A, KC_D, KC_Y)
# SUBS(COMBO0784,  "American ",  KC_C, KC_M, KC_R)
# SUBS(COMBO0785,  "but she ",  KC_BSPC, KC_B, KC_S)
# SUBS(COMBO0786,  "after the ",  KC_F, KC_H, KC_T)
# SUBS(COMBO0787,  "aught",  KC_G, KC_H, KC_U)
# SUBS(COMBO0788,  "breath",  KC_B, KC_H, KC_R)
# SUBS(COMBO0789,  "myself ",  KC_BSPC, KC_F, KC_M)
# SUBS(COMBO0790,  "there was no ",  KC_O, KC_S, KC_W)
# SUBS(COMBO0791,  "enough to ",  KC_E, KC_G, KC_H)
# SUBS(COMBO0792,  "ghts ",  KC_G, KC_H, KC_S)
# SUBS(COMBO0793,  "followed ",  KC_F, KC_L, KC_W)
# SUBS(COMBO0794,  "suppo",  KC_P, KC_S, KC_U)
# SUBS(COMBO0795,  "black ",  KC_BSPC, KC_B, KC_K)
# SUBS(COMBO0796,  "reached ",  KC_C, KC_D, KC_H)
# SUBS(COMBO0797,  "feeling ",  KC_F, KC_G, KC_L)
# SUBS(COMBO0798,  "immediately ",  KC_D, KC_I, KC_L)
# SUBS(COMBO0799,  "along ",  KC_A, KC_G, KC_O)
# SUBS(COMBO0800,  "service",  KC_R, KC_S, KC_V)
# SUBS(COMBO0801,  "matter",  KC_E, KC_M, KC_R)
# SUBS(COMBO0802,  "figure ",  KC_F, KC_G, KC_R)
# SUBS(COMBO0803,  "friends ",  KC_D, KC_F, KC_I)
# SUBS(COMBO0804,  "political ",  KC_C, KC_I, KC_P)
# SUBS(COMBO0805,  "women ",  KC_SPC, KC_M, KC_W)
# SUBS(COMBO0806,  "organization",  KC_G, KC_Z)
# SUBS(COMBO0807,  "actually ",  KC_A, KC_C, KC_Y)
# SUBS(COMBO0808,  "express",  KC_S, KC_X)
# SUBS(COMBO0809,  "began ",  KC_A, KC_B, KC_N)
# SUBS(COMBO0810,  "live",  KC_I, KC_L, KC_V)
# SUBS(COMBO0811,  "know what ",  KC_K, KC_O, KC_W)
# SUBS(COMBO0812,  "including ",  KC_C, KC_G, KC_I)
# SUBS(COMBO0813,  "wonder",  KC_D, KC_E, KC_W)
# SUBS(COMBO0814,  "minute",  KC_BSPC, KC_M, KC_U)
# SUBS(COMBO0815,  "you will ",  KC_U, KC_W, KC_Y)
# SUBS(COMBO0816,  "did not want ",  KC_I, KC_O, KC_W)
# SUBS(COMBO0817,  "plan",  KC_A, KC_L, KC_P)
# SUBS(COMBO0818,  "particular ",  KC_SPC, KC_P, KC_U)
# SUBS(COMBO0819,  "public",  KC_B, KC_C, KC_U)
# SUBS(COMBO0820,  "product",  KC_P, KC_R, KC_U)
# SUBS(COMBO0821,  "rious ",  KC_I, KC_R, KC_U)
# SUBS(COMBO0822,  "as they ",  KC_S, KC_T, KC_Y)
# SUBS(COMBO0823,  "minutes ",  KC_M, KC_S, KC_U)
# SUBS(COMBO0824,  "a moment ",  KC_A, KC_M, KC_O)
# SUBS(COMBO0825,  "in which ",  KC_SPC, KC_C, KC_W)
# SUBS(COMBO0826,  "clear",  KC_C, KC_E, KC_L)
# SUBS(COMBO0827,  "he could not ",  KC_C, KC_H, KC_U)
# SUBS(COMBO0828,  "conversation",  KC_C, KC_R, KC_V)
# SUBS(COMBO0829,  "understanding ",  KC_I, KC_S, KC_U)
# SUBS(COMBO0830,  "pulled ",  KC_D, KC_L, KC_U)
# SUBS(COMBO0831,  "practic",  KC_A, KC_I, KC_P)
# SUBS(COMBO0832,  "expression",  KC_E, KC_P, KC_X)
# SUBS(COMBO0833,  "parent",  KC_A, KC_N, KC_P)
# SUBS(COMBO0834,  "began to ",  KC_A, KC_B, KC_O)
# SUBS(COMBO0835,  "brother",  KC_B, KC_O, KC_R)
# SUBS(COMBO0836,  "she could not ",  KC_N, KC_S, KC_U)
# SUBS(COMBO0837,  "power",  KC_BSPC, KC_P, KC_W)
# SUBS(COMBO0838,  "working ",  KC_BSPC, KC_G, KC_W)
# SUBS(COMBO0839,  "you were ",  KC_O, KC_W, KC_Y)
# SUBS(COMBO0840,  "for example ",  KC_F, KC_X)
# SUBS(COMBO0841,  "manage",  KC_A, KC_G, KC_M)
# SUBS(COMBO0842,  "for her ",  KC_F, KC_H, KC_R)
# SUBS(COMBO0843,  "up the ",  KC_H, KC_P, KC_U)
# SUBS(COMBO0844,  "the ground ",  KC_G, KC_O, KC_U)
# SUBS(COMBO0845,  "expression ",  KC_SPC, KC_BSPC, KC_X)
# SUBS(COMBO0846,  "beautiful ",  KC_SPC, KC_B, KC_F)
# SUBS(COMBO0847,  "kind of ",  KC_SPC, KC_F, KC_K)
# SUBS(COMBO0848,  "difficult",  KC_D, KC_F, KC_U)
# SUBS(COMBO0849,  "forward ",  KC_D, KC_F, KC_W)
# SUBS(COMBO0850,  "expect",  KC_BSPC, KC_P, KC_X)
# SUBS(COMBO0851,  "given ",  KC_E, KC_N, KC_V)
# SUBS(COMBO0852,  "large",  KC_E, KC_G, KC_L)
# SUBS(COMBO0853,  "toward the ",  KC_A, KC_D, KC_O)
# SUBS(COMBO0854,  "taking ",  KC_G, KC_I, KC_K)
# SUBS(COMBO0855,  "quickly ",  KC_K, KC_Q)
# SUBS(COMBO0856,  "public ",  KC_B, KC_C, KC_L)
# SUBS(COMBO0857,  "the right ",  KC_G, KC_H, KC_R)
# SUBS(COMBO0858,  "before the ",  KC_BSPC, KC_B, KC_F)
# SUBS(COMBO0859,  "building",  KC_B, KC_L, KC_U)
# SUBS(COMBO0860,  "was going ",  KC_G, KC_S, KC_W)
# SUBS(COMBO0861,  "you think ",  KC_K, KC_T, KC_Y)
# SUBS(COMBO0862,  "doing ",  KC_G, KC_I, KC_O)
# SUBS(COMBO0863,  "questions ",  KC_SPC, KC_BSPC, KC_Q)
# SUBS(COMBO0864,  "covered ",  KC_C, KC_O, KC_V)
# SUBS(COMBO0865,  "pleas",  KC_E, KC_L, KC_P)
# SUBS(COMBO0866,  "environment",  KC_E, KC_M, KC_V)
# SUBS(COMBO0867,  "from his ",  KC_F, KC_H, KC_I)
# SUBS(COMBO0868,  "serve",  KC_E, KC_S, KC_V)
# SUBS(COMBO0869,  "illed ",  KC_E, KC_I, KC_L)
# SUBS(COMBO0870,  "ulation",  KC_A, KC_L, KC_U)
# SUBS(COMBO0871,  "iled ",  KC_D, KC_E, KC_L)
# SUBS(COMBO0872,  "ject",  KC_C, KC_J)
# SUBS(COMBO0873,  "when they ",  KC_N, KC_W, KC_Y)
# SUBS(COMBO0874,  "conversation ",  KC_C, KC_N, KC_V)
# SUBS(COMBO0875,  "support",  KC_O, KC_P, KC_U)
# SUBS(COMBO0876,  "was going to ",  KC_G, KC_I, KC_W)
# SUBS(COMBO0877,  "may be ",  KC_A, KC_B, KC_M)
# SUBS(COMBO0878,  "company ",  KC_BSPC, KC_C, KC_Y)
# SUBS(COMBO0879,  "difference",  KC_D, KC_F, KC_N)
# SUBS(COMBO0880,  "result",  KC_L, KC_R, KC_U)
# SUBS(COMBO0881,  "feel ",  KC_E, KC_F, KC_L)
# SUBS(COMBO0882,  "to find ",  KC_F, KC_N, KC_T)
# SUBS(COMBO0883,  "the back ",  KC_B, KC_C, KC_K)
# SUBS(COMBO0884,  "become ",  KC_B, KC_C, KC_M)
# SUBS(COMBO0885,  "function",  KC_F, KC_I, KC_U)
# SUBS(COMBO0886,  "aughter ",  KC_H, KC_R, KC_U)
# SUBS(COMBO0887,  "the rest of ",  KC_E, KC_F, KC_R)
# SUBS(COMBO0888,  "his face ",  KC_A, KC_F, KC_H)
# SUBS(COMBO0889,  "roduction ",  KC_C, KC_R, KC_U)
# SUBS(COMBO0890,  "New York ",  KC_BSPC, KC_K, KC_Y)
# SUBS(COMBO0891,  "the fact that ",  KC_E, KC_F, KC_H)
# SUBS(COMBO0892,  "you want ",  KC_N, KC_U, KC_Y)
# SUBS(COMBO0893,  "brother ",  KC_B, KC_H, KC_O)
# SUBS(COMBO0894,  "lication",  KC_I, KC_L, KC_T)
# SUBS(COMBO0895,  "I could not ",  KC_C, KC_L, KC_U)
# SUBS(COMBO0896,  "of my ",  KC_F, KC_M, KC_O)
# SUBS(COMBO0897,  "ives ",  KC_I, KC_S, KC_V)
# SUBS(COMBO0898,  "ically ",  KC_C, KC_L, KC_Y)
# SUBS(COMBO0899,  "countr",  KC_O, KC_R, KC_U)
# SUBS(COMBO0900,  "patient",  KC_E, KC_I, KC_P)
# SUBS(COMBO0901,  "rive",  KC_E, KC_R, KC_V)
# SUBS(COMBO0902,  "country ",  KC_C, KC_U, KC_Y)
# SUBS(COMBO0903,  "leave ",  KC_A, KC_L, KC_V)
# SUBS(COMBO0904,  "finger",  KC_F, KC_G, KC_I)
# SUBS(COMBO0905,  "chapter ",  KC_C, KC_H, KC_P)
# SUBS(COMBO0906,  "surprise",  KC_I, KC_P, KC_U)
# SUBS(COMBO0907,  "the table ",  KC_A, KC_B, KC_H)
# SUBS(COMBO0908,  "back to the ",  KC_C, KC_K, KC_T)
# SUBS(COMBO0909,  "problem ",  KC_SPC, KC_M, KC_P)
# SUBS(COMBO0910,  "power ",  KC_SPC, KC_P, KC_W)
# SUBS(COMBO0911,  "ption",  KC_I, KC_O, KC_P)
# SUBS(COMBO0912,  "to know ",  KC_K, KC_T, KC_W)
# SUBS(COMBO0913,  "ctor",  KC_C, KC_O, KC_T)
# SUBS(COMBO0914,  "because of ",  KC_B, KC_F, KC_O)
# SUBS(COMBO0915,  "partment ",  KC_M, KC_P, KC_R)
# SUBS(COMBO0916,  "significan",  KC_F, KC_G, KC_N)
# SUBS(COMBO0917,  "some of ",  KC_E, KC_F, KC_M)
# SUBS(COMBO0918,  "building ",  KC_G, KC_L, KC_U)
# SUBS(COMBO0919,  "if he ",  KC_E, KC_F, KC_I)
# SUBS(COMBO0920,  "form ",  KC_F, KC_M, KC_R)
# SUBS(COMBO0921,  "further ",  KC_F, KC_R, KC_U)
# SUBS(COMBO0922,  "and you ",  KC_D, KC_U, KC_Y)
# SUBS(COMBO0923,  "bject",  KC_J, KC_T)
# SUBS(COMBO0924,  "cking ",  KC_BSPC, KC_C, KC_K)
# SUBS(COMBO0925,  "the end of ",  KC_D, KC_E, KC_F)
# SUBS(COMBO0926,  "history ",  KC_H, KC_S, KC_Y)
# SUBS(COMBO0927,  "situation",  KC_A, KC_I, KC_U)
# SUBS(COMBO0928,  "with him ",  KC_BSPC, KC_M, KC_W)
# SUBS(COMBO0929,  "that would ",  KC_T, KC_U, KC_W)
# SUBS(COMBO0930,  "not even ",  KC_N, KC_O, KC_V)
# SUBS(COMBO0931,  "personal",  KC_L, KC_O, KC_P)
# SUBS(COMBO0932,  "to say ",  KC_O, KC_S, KC_Y)
# SUBS(COMBO0933,  "smiled ",  KC_D, KC_L, KC_S)
# SUBS(COMBO0934,  "often ",  KC_F, KC_N, KC_O)
# SUBS(COMBO0935,  "keep ",  KC_SPC, KC_K, KC_P)
# SUBS(COMBO0936,  "must be ",  KC_B, KC_M, KC_U)
# SUBS(COMBO0937,  "remain",  KC_I, KC_M, KC_R)
# SUBS(COMBO0938,  "moved ",  KC_D, KC_E, KC_M)
# SUBS(COMBO0939,  "the second ",  KC_C, KC_H, KC_O)
# SUBS(COMBO0940,  "determin",  KC_D, KC_M, KC_R)
# SUBS(COMBO0941,  "part of the ",  KC_SPC, KC_F, KC_P)
# SUBS(COMBO0942,  "shoulder ",  KC_L, KC_R, KC_S)
# SUBS(COMBO0943,  "education",  KC_A, KC_C, KC_U)
# SUBS(COMBO0944,  "the first time ",  KC_F, KC_I, KC_M)
# SUBS(COMBO0945,  "rms ",  KC_M, KC_R, KC_S)
# SUBS(COMBO0946,  "upon ",  KC_N, KC_P, KC_U)
# SUBS(COMBO0947,  "to keep ",  KC_BSPC, KC_K, KC_P)
# SUBS(COMBO0948,  "waiting ",  KC_G, KC_N, KC_W)
# SUBS(COMBO0949,  "he looked ",  KC_D, KC_K, KC_O)
# SUBS(COMBO0950,  "explain",  KC_E, KC_L, KC_X)
# SUBS(COMBO0951,  "like the ",  KC_E, KC_I, KC_K)
# SUBS(COMBO0952,  "the kitchen ",  KC_C, KC_I, KC_K)
# SUBS(COMBO0953,  "city ",  KC_C, KC_T, KC_Y)
# SUBS(COMBO0954,  "human ",  KC_A, KC_M, KC_U)
# SUBS(COMBO0955,  "rong ",  KC_G, KC_O, KC_R)
# SUBS(COMBO0956,  "full",  KC_F, KC_L, KC_U)
# SUBS(COMBO0957,  "ulation ",  KC_A, KC_N, KC_U)
# SUBS(COMBO0958,  "whatever ",  KC_BSPC, KC_V, KC_W)
# SUBS(COMBO0959,  "might be ",  KC_B, KC_I, KC_M)
# SUBS(COMBO0960,  "when you ",  KC_H, KC_U, KC_Y)
# SUBS(COMBO0961,  "uation ",  KC_A, KC_O, KC_U)
# SUBS(COMBO0962,  "management ",  KC_E, KC_G, KC_M)
# SUBS(COMBO0963,  "could have ",  KC_C, KC_H, KC_V)
# SUBS(COMBO0964,  "about it ",  KC_A, KC_B, KC_I)
# SUBS(COMBO0965,  "individual ",  KC_BSPC, KC_U, KC_V)
# SUBS(COMBO0966,  "for a moment ",  KC_A, KC_F, KC_M)
# SUBS(COMBO0967,  "what you ",  KC_A, KC_U, KC_W)
# SUBS(COMBO0968,  "necessary ",  KC_C, KC_N, KC_Y)
# SUBS(COMBO0969,  "suggest",  KC_E, KC_G, KC_S)
# SUBS(COMBO0970,  "who had ",  KC_A, KC_H, KC_O)
# SUBS(COMBO0971,  "quite ",  KC_SPC, KC_Q, KC_U)
# SUBS(COMBO0972,  "plication",  KC_I, KC_L, KC_P)
# SUBS(COMBO0973,  "tching ",  KC_C, KC_G, KC_H)
# SUBS(COMBO0974,  "mouth ",  KC_M, KC_T, KC_U)
# SUBS(COMBO0975,  "they would ",  KC_L, KC_W, KC_Y)
# SUBS(COMBO0976,  "be able to ",  KC_B, KC_L, KC_O)
# SUBS(COMBO0977,  "rely ",  KC_L, KC_R, KC_Y)
# SUBS(COMBO0978,  "up and ",  KC_A, KC_P, KC_U)
# SUBS(COMBO0979,  "fingers ",  KC_F, KC_I, KC_R)
# SUBS(COMBO0980,  "atching ",  KC_C, KC_H, KC_I)
# SUBS(COMBO0981,  "ously ",  KC_L, KC_U, KC_Y)
# SUBS(COMBO0982,  "fully ",  KC_F, KC_U, KC_Y)
# SUBS(COMBO0983,  "gave ",  KC_A, KC_E, KC_V)
# SUBS(COMBO0984,  "iously ",  KC_L, KC_S, KC_Y)
# SUBS(COMBO0985,  "the best ",  KC_B, KC_E, KC_S)
# SUBS(COMBO0986,  "the floor ",  KC_F, KC_L, KC_R)
# SUBS(COMBO0987,  "which is ",  KC_C, KC_I, KC_W)
# SUBS(COMBO0988,  "it would be ",  KC_B, KC_I, KC_W)
# SUBS(COMBO0989,  "days ",  KC_D, KC_S, KC_Y)
# SUBS(COMBO0990,  "ark ",  KC_A, KC_K, KC_R)
# SUBS(COMBO0991,  "expected ",  KC_D, KC_X)
# SUBS(COMBO0992,  "significant",  KC_F, KC_I, KC_N)
# SUBS(COMBO0993,  "for you ",  KC_F, KC_R, KC_Y)
# SUBS(COMBO0994,  "side of the ",  KC_D, KC_F, KC_O)
# SUBS(COMBO0995,  "money ",  KC_E, KC_M, KC_Y)
# SUBS(COMBO0996,  "such a ",  KC_H, KC_S, KC_U)
# SUBS(COMBO0997,  "should have ",  KC_H, KC_S, KC_V)
# SUBS(COMBO0998,  "completely ",  KC_C, KC_P, KC_Y)
# SUBS(COMBO0999,  "answer ",  KC_E, KC_S, KC_W)
# SUBS(COMBO1000,  "anyone ",  KC_A, KC_E, KC_Y)
# SUBS(COMBO1001,  "we can ",  KC_C, KC_N, KC_W)
# SUBS(COMBO1002,  "know that ",  KC_A, KC_K, KC_O)
# ...
# SUBS(COMBO1695,  "a dozen ",  KC_D, KC_N, KC_Z)
# SUBS(COMBO1696,  "azed ",  KC_BSPC, KC_E, KC_Z)
# SUBS(COMBO1697,  "the existence of ",  KC_H, KC_O, KC_X)
# SUBS(COMBO1698,  "that she'd ",  KC_QUOT, KC_S, KC_T)
# SUBS(COMBO1699,  "questioning ",  KC_G, KC_Q)
# SUBS(COMBO1700,  "his expression ",  KC_BSPC, KC_H, KC_X)
# SUBS(COMBO1701,  "exhibit",  KC_B, KC_E, KC_X)
# SUBS(COMBO1702,  "I was just ",  KC_I, KC_J, KC_W)
# SUBS(COMBO1703,  "headquarters ",  KC_SPC, KC_H, KC_Q)
# SUBS(COMBO1704,  "let's go ",  KC_QUOT, KC_G, KC_L)
# SUBS(COMBO1705,  "liquid ",  KC_BSPC, KC_L, KC_Q)
# SUBS(COMBO1706,  "qualities ",  KC_L, KC_Q, KC_U)
# SUBS(COMBO1707,  "that's what I ",  KC_QUOT, KC_I, KC_W)
# SUBS(COMBO1708,  "is just ",  KC_I, KC_J, KC_S)
# SUBS(COMBO1709,  "compared with ",  KC_M, KC_P, KC_W)
# SUBS(COMBO1710,  "extensive ",  KC_I, KC_V, KC_X)
# SUBS(COMBO1711,  "question of ",  KC_F, KC_O, KC_Q)
# SUBS(COMBO1712,  "questioned ",  KC_O, KC_Q, KC_U)
# SUBS(COMBO1713,  "what's wrong ",  KC_QUOT, KC_BSPC, KC_R)
# SUBS(COMBO1714,  "horizon",  KC_H, KC_R, KC_Z)
# SUBS(COMBO1715,  "the extent ",  KC_H, KC_T, KC_X)
# SUBS(COMBO1716,  "expression of ",  KC_F, KC_I, KC_X)
# SUBS(COMBO1717,  "Jewish ",  KC_BSPC, KC_J, KC_W)
# SUBS(COMBO1718,  "her father's ",  KC_QUOT, KC_F, KC_H)
# SUBS(COMBO1719,  "acquire",  KC_C, KC_I, KC_Q)
# SUBS(COMBO1720,  "characterized by ",  KC_B, KC_Z)
# SUBS(COMBO1721,  "an example ",  KC_A, KC_M, KC_X)
# SUBS(COMBO1722,  "I'm just ",  KC_QUOT, KC_BSPC, KC_J)
# SUBS(COMBO1723,  "her gaze ",  KC_G, KC_H, KC_Z)
# SUBS(COMBO1724,  "the box ",  KC_SPC, KC_B, KC_X)
# SUBS(COMBO1725,  "that's right ",  KC_QUOT, KC_R, KC_T)
# SUBS(COMBO1726,  "reject",  KC_C, KC_J, KC_R)
# SUBS(COMBO1727,  "the majority of ",  KC_F, KC_J, KC_T)
# SUBS(COMBO1728,  "requirement ",  KC_M, KC_Q, KC_R)
# SUBS(COMBO1729,  "six months ",  KC_H, KC_S, KC_X)
# SUBS(COMBO1730,  "you're the ",  KC_QUOT, KC_T, KC_U)
# SUBS(COMBO1731,  "I'll have ",  KC_QUOT, KC_H, KC_V)
# SUBS(COMBO1732,  "injury ",  KC_I, KC_J, KC_R)
# SUBS(COMBO1733,  "when you're ",  KC_QUOT, KC_U, KC_W)
# SUBS(COMBO1734,  "equality ",  KC_BSPC, KC_Q, KC_Y)
# SUBS(COMBO1735,  "you'll have ",  KC_QUOT, KC_V, KC_Y)
# SUBS(COMBO1736,  "izing ",  KC_G, KC_I, KC_Z)
# SUBS(COMBO1737,  "they'd ",  KC_SPC, KC_QUOT, KC_D)
# SUBS(COMBO1738,  "walked over ",  KC_K, KC_O, KC_V)
# SUBS(COMBO1739,  "explaining ",  KC_G, KC_L, KC_X)
# SUBS(COMBO1740,  "inquir",  KC_N, KC_Q, KC_R)
# SUBS(COMBO1741,  "we'd ",  KC_QUOT, KC_D, KC_W)
# SUBS(COMBO1742,  "she realized ",  KC_L, KC_S, KC_Z)
# SUBS(COMBO1743,  "acquired ",  KC_D, KC_I, KC_Q)
# SUBS(COMBO1744,  "he's not ",  KC_QUOT, KC_H, KC_S)
# SUBS(COMBO1745,  "looked over ",  KC_BSPC, KC_K, KC_V)
# SUBS(COMBO1746,  "it's been ",  KC_QUOT, KC_B, KC_S)
# SUBS(COMBO1747,  "acquaintance",  KC_C, KC_E, KC_Q)
# SUBS(COMBO1748,  "each other's ",  KC_SPC, KC_QUOT, KC_C)
# SUBS(COMBO1749,  "objectives ",  KC_C, KC_J, KC_V)
# SUBS(COMBO1750,  "exclusive",  KC_C, KC_V, KC_X)
# SUBS(COMBO1751,  "we've got ",  KC_QUOT, KC_V, KC_W)
# SUBS(COMBO1752,  "the question of ",  KC_O, KC_Q, KC_T)
# SUBS(COMBO1753,  "walked over to ",  KC_K, KC_V, KC_W)
# SUBS(COMBO1754,  "but that's ",  KC_QUOT, KC_B, KC_U)
# SUBS(COMBO1755,  "jurisdiction",  KC_C, KC_J, KC_U)
# SUBS(COMBO1756,  "and you're ",  KC_QUOT, KC_A, KC_U)
# SUBS(COMBO1757,  "I'm going ",  KC_QUOT, KC_G, KC_M)
# SUBS(COMBO1758,  "who's ",  KC_QUOT, KC_S, KC_W)
# SUBS(COMBO1759,  "that you're ",  KC_QUOT, KC_BSPC, KC_U)
# SUBS(COMBO1760,  "mixture ",  KC_I, KC_U, KC_X)
# SUBS(COMBO1761,  "we'll ",  KC_QUOT, KC_L, KC_W)
# SUBS(COMBO1762,  "who'd ",  KC_QUOT, KC_BSPC, KC_D)
# SUBS(COMBO1763,  "expansion ",  KC_A, KC_O, KC_X)
# SUBS(COMBO1764,  "civilization ",  KC_V, KC_Z)
# SUBS(COMBO1765,  "to realize ",  KC_I, KC_T, KC_Z)
# SUBS(COMBO1766,  "except for the ",  KC_F, KC_H, KC_X)
# SUBS(COMBO1767,  "complexity ",  KC_C, KC_X, KC_Y)
# SUBS(COMBO1768,  "jeans ",  KC_A, KC_J, KC_S)
# SUBS(COMBO1769,  "it's like ",  KC_QUOT, KC_BSPC, KC_K)
# SUBS(COMBO1770,  "consequences of ",  KC_O, KC_Q, KC_S)
# SUBS(COMBO1771,  "jealous",  KC_J, KC_O, KC_S)
# SUBS(COMBO1772,  "reeze ",  KC_E, KC_R, KC_Z)
# SUBS(COMBO1773,  "children's ",  KC_QUOT, KC_BSPC, KC_C)
# SUBS(COMBO1774,  "explicit",  KC_I, KC_L, KC_X)
# SUBS(COMBO1775,  "subsequently ",  KC_B, KC_Q, KC_Y)
# SUBS(COMBO1776,  "what are you talking about ",  KC_B, KC_K, KC_Y)
# SUBS(COMBO1777,  "was just a ",  KC_A, KC_J, KC_W)
# SUBS(COMBO1778,  "exchanged ",  KC_C, KC_G, KC_X)
# SUBS(COMBO1779,  "that I'm ",  KC_QUOT, KC_A, KC_M)
# SUBS(COMBO1780,  "acquisition ",  KC_I, KC_Q, KC_S)
# SUBS(COMBO1781,  "he's a ",  KC_QUOT, KC_A, KC_H)
# SUBS(COMBO1782,  "frequent ",  KC_F, KC_N, KC_Q)
# SUBS(COMBO1783,  "journalis",  KC_J, KC_R, KC_U)
# SUBS(COMBO1784,  "emphasize",  KC_P, KC_Z)
# SUBS(COMBO1785,  "equilibrium ",  KC_B, KC_E, KC_Q)
# SUBS(COMBO1786,  "the quality of ",  KC_O, KC_Q, KC_Y)
# SUBS(COMBO1787,  "I'm glad ",  KC_QUOT, KC_D, KC_I)
# SUBS(COMBO1788,  "just do not ",  KC_D, KC_J, KC_S)
# SUBS(COMBO1789,  "I'll take ",  KC_QUOT, KC_L, KC_T)
# SUBS(COMBO1790,  "there's something ",  KC_QUOT, KC_G, KC_S)
# SUBS(COMBO1791,  "equations ",  KC_E, KC_O, KC_Q)
# SUBS(COMBO1792,  "horizon ",  KC_H, KC_I, KC_Z)
# SUBS(COMBO1793,  "jewish",  KC_J, KC_S, KC_W)
# SUBS(COMBO1794,  "have known ",  KC_A, KC_K, KC_V)
# SUBS(COMBO1795,  "jurisdiction ",  KC_C, KC_I, KC_J)
# SUBS(COMBO1796,  "exciting ",  KC_G, KC_I, KC_X)
# SUBS(COMBO1797,  "just one ",  KC_E, KC_J, KC_T)
# SUBS(COMBO1798,  "explanations ",  KC_L, KC_S, KC_X)
# SUBS(COMBO1799,  "realization ",  KC_N, KC_R, KC_Z)
# SUBS(COMBO1800,  "quantity ",  KC_Q, KC_U, KC_Y)
# SUBS(COMBO1801,  "International Journal of ",  KC_F, KC_I, KC_J)
# SUBS(COMBO1802,  "we're not ",  KC_QUOT, KC_N, KC_W)
# SUBS(COMBO1803,  "the major ",  KC_J, KC_R, KC_T)
# SUBS(COMBO1804,  "breeze ",  KC_SPC, KC_B, KC_Z)
# SUBS(COMBO1805,  "the experience ",  KC_H, KC_P, KC_X)
# SUBS(COMBO1806,  "just because ",  KC_B, KC_C, KC_J)
# SUBS(COMBO1807,  "execution ",  KC_N, KC_U, KC_X)
# SUBS(COMBO1808,  "injured ",  KC_D, KC_I, KC_J)
# SUBS(COMBO1809,  "frozen ",  KC_SPC, KC_F, KC_Z)
# SUBS(COMBO1810,  "realizing ",  KC_G, KC_L, KC_Z)
# SUBS(COMBO1811,  "adjusted ",  KC_A, KC_J, KC_T)
# SUBS(COMBO1812,  "a major ",  KC_A, KC_J, KC_R)
# SUBS(COMBO1813,  "justif",  KC_BSPC, KC_F, KC_J)
# SUBS(COMBO1814,  "you'll have to ",  KC_QUOT, KC_BSPC, KC_V)
# SUBS(COMBO1815,  "it's going to ",  KC_QUOT, KC_I, KC_S)
# SUBS(COMBO1816,  "I think it's ",  KC_QUOT, KC_K, KC_S)
# SUBS(COMBO1817,  "examining ",  KC_G, KC_M, KC_X)
# SUBS(COMBO1818,  "injuries ",  KC_J, KC_R, KC_S)
# SUBS(COMBO1819,  "an example of ",  KC_F, KC_M, KC_X)
# SUBS(COMBO1820,  "I'd been ",  KC_QUOT, KC_B, KC_N)
# SUBS(COMBO1821,  "I'll tell you ",  KC_QUOT, KC_E, KC_T)
# SUBS(COMBO1822,  "journalist",  KC_J, KC_O, KC_R)
# SUBS(COMBO1823,  "I'm so ",  KC_QUOT, KC_M, KC_S)
# SUBS(COMBO1824,  "quantitative ",  KC_SPC, KC_Q, KC_V)
# SUBS(COMBO1825,  "apologize",  KC_L, KC_P, KC_Z)
# SUBS(COMBO1826,  "my father's ",  KC_QUOT, KC_F, KC_M)
# SUBS(COMBO1827,  "said quietly ",  KC_L, KC_Q, KC_S)
# SUBS(COMBO1828,  "expenditure",  KC_D, KC_U, KC_X)
# SUBS(COMBO1829,  "rejected ",  KC_D, KC_J, KC_R)
# SUBS(COMBO1830,  "women's ",  KC_QUOT, KC_M, KC_W)
# SUBS(COMBO1831,  "let's get ",  KC_QUOT, KC_L, KC_S)
# SUBS(COMBO1832,  "just a few ",  KC_A, KC_F, KC_J)
# SUBS(COMBO1833,  "I realized ",  KC_D, KC_I, KC_Z)
# SUBS(COMBO1834,  "adjustment",  KC_A, KC_E, KC_J)
# SUBS(COMBO1835,  "sized ",  KC_I, KC_S, KC_Z)
# SUBS(COMBO1836,  "that's why I ",  KC_QUOT, KC_H, KC_W)
# SUBS(COMBO1837,  "the requirements ",  KC_M, KC_Q, KC_T)
# SUBS(COMBO1838,  "what I'm ",  KC_QUOT, KC_A, KC_W)
# SUBS(COMBO1839,  "majesty ",  KC_J, KC_S, KC_Y)
# SUBS(COMBO1840,  "I'll get ",  KC_QUOT, KC_E, KC_G)
# SUBS(COMBO1841,  "just wanted ",  KC_J, KC_U, KC_W)
# SUBS(COMBO1842,  "oxygen ",  KC_O, KC_X, KC_Y)
# SUBS(COMBO1843,  "she'll ",  KC_QUOT, KC_E, KC_S)
# SUBS(COMBO1844,  "objection",  KC_B, KC_I, KC_J)
# SUBS(COMBO1845,  "we'll be ",  KC_QUOT, KC_B, KC_W)
# SUBS(COMBO1846,  "if it's ",  KC_QUOT, KC_F, KC_I)
# SUBS(COMBO1847,  "just about ",  KC_A, KC_B, KC_J)
# SUBS(COMBO1848,  "a job ",  KC_A, KC_J, KC_O)
# SUBS(COMBO1849,  "joining ",  KC_G, KC_I, KC_J)
# SUBS(COMBO1850,  "the subject of ",  KC_B, KC_F, KC_J)
# SUBS(COMBO1851,  "I've seen ",  KC_QUOT, KC_S, KC_V)
# SUBS(COMBO1852,  "exclusive ",  KC_U, KC_V, KC_X)
# SUBS(COMBO1853,  "jerked ",  KC_D, KC_E, KC_J)
# SUBS(COMBO1854,  "just wanted to ",  KC_J, KC_T, KC_W)
# SUBS(COMBO1855,  "the expression ",  KC_H, KC_I, KC_X)
# SUBS(COMBO1856,  "gazed ",  KC_E, KC_G, KC_Z)
# SUBS(COMBO1857,  "just a little ",  KC_A, KC_I, KC_J)
# SUBS(COMBO1858,  "king's ",  KC_QUOT, KC_G, KC_K)
# SUBS(COMBO1859,  "do not even know ",  KC_E, KC_K, KC_V)
# SUBS(COMBO1860,  "I'm sure you ",  KC_QUOT, KC_S, KC_Y)
# SUBS(COMBO1861,  "qualified ",  KC_F, KC_L, KC_Q)
# SUBS(COMBO1862,  "the object ",  KC_B, KC_E, KC_J)
# SUBS(COMBO1863,  "requirements of ",  KC_O, KC_Q, KC_R)
# SUBS(COMBO1864,  "that's what you ",  KC_QUOT, KC_S, KC_U)
# SUBS(COMBO1865,  "puzzle",  KC_P, KC_U, KC_Z)
# SUBS(COMBO1866,  "the next few ",  KC_F, KC_N, KC_X)
# SUBS(COMBO1867,  "apologize ",  KC_SPC, KC_P, KC_Z)
# SUBS(COMBO1868,  "think you're ",  KC_QUOT, KC_R, KC_Y)
# SUBS(COMBO1869,  "the consequences ",  KC_C, KC_H, KC_Q)
# SUBS(COMBO1870,  "qualitative ",  KC_Q, KC_U, KC_V)
# SUBS(COMBO1871,  "exploring ",  KC_G, KC_O, KC_X)
# SUBS(COMBO1872,  "the maximum ",  KC_T, KC_U, KC_X)
# SUBS(COMBO1873,  "if he'd ",  KC_QUOT, KC_BSPC, KC_F)
# SUBS(COMBO1874,  "I'm so sorry ",  KC_QUOT, KC_R, KC_S)
# SUBS(COMBO1875,  "characterization ",  KC_C, KC_O, KC_Z)
# SUBS(COMBO1876,  "consequence of ",  KC_N, KC_O, KC_Q)
# SUBS(COMBO1877,  "the extent to which ",  KC_C, KC_H, KC_X)
# SUBS(COMBO1878,  "and he's ",  KC_QUOT, KC_D, KC_H)
# SUBS(COMBO1879,  "he's going to ",  KC_QUOT, KC_G, KC_H)
# SUBS(COMBO1880,  "puzzled ",  KC_BSPC, KC_U, KC_Z)
# SUBS(COMBO1881,  "horizontal ",  KC_H, KC_O, KC_Z)
# SUBS(COMBO1882,  "but I'm not ",  KC_QUOT, KC_B, KC_M)
# SUBS(COMBO1883,  "were just ",  KC_E, KC_J, KC_W)
# SUBS(COMBO1884,  "exploded ",  KC_D, KC_O, KC_X)
# SUBS(COMBO1885,  "they'd been ",  KC_QUOT, KC_D, KC_Y)
# SUBS(COMBO1886,  "boxes ",  KC_BSPC, KC_B, KC_X)
# SUBS(COMBO1887,  "inquiry ",  KC_Q, KC_R, KC_Y)
# SUBS(COMBO1888,  "explicitly ",  KC_P, KC_X, KC_Y)
# SUBS(COMBO1889,  "you're going to ",  KC_QUOT, KC_G, KC_Y)
# SUBS(COMBO1890,  "seized ",  KC_E, KC_S, KC_Z)
# SUBS(COMBO1891,  "when she'd ",  KC_QUOT, KC_D, KC_S)
# SUBS(COMBO1892,  "when he'd ",  KC_QUOT, KC_D, KC_N)
# SUBS(COMBO1893,  "justifi",  KC_F, KC_J, KC_U)
# SUBS(COMBO1894,  "jump ",  KC_J, KC_P, KC_U)
# SUBS(COMBO1895,  "I've got to ",  KC_QUOT, KC_I, KC_V)
# SUBS(COMBO1896,  "required for ",  KC_F, KC_I, KC_Q)
# SUBS(COMBO1897,  "Switzerland ",  KC_W, KC_Z)
# SUBS(COMBO1898,  "citizenship ",  KC_I, KC_P, KC_Z)
# SUBS(COMBO1899,  "justified ",  KC_D, KC_F, KC_J)
# SUBS(COMBO1900,  "the horizon ",  KC_H, KC_T, KC_Z)
# SUBS(COMBO1901,  "he'd be ",  KC_QUOT, KC_B, KC_H)
# SUBS(COMBO1902,  "we'll have ",  KC_QUOT, KC_L, KC_V)
# SUBS(COMBO1903,  "nquired ",  KC_D, KC_N, KC_Q)
# SUBS(COMBO1904,  "brother's ",  KC_QUOT, KC_B, KC_R)
# SUBS(COMBO1905,  "explain the ",  KC_A, KC_H, KC_X)
# SUBS(COMBO1906,  "for example, in ",  KC_F, KC_L, KC_X)
# SUBS(COMBO1907,  "inequalit",  KC_I, KC_L, KC_Q)
# SUBS(COMBO1908,  "equal to ",  KC_L, KC_Q, KC_T)
# SUBS(COMBO1909,  "I'll have to ",  KC_QUOT, KC_A, KC_V)
# SUBS(COMBO1910,  "unexpectedly ",  KC_U, KC_X, KC_Y)
# SUBS(COMBO1911,  "magazines ",  KC_G, KC_M, KC_Z)
# SUBS(COMBO1912,  "trying to make ",  KC_G, KC_K, KC_Y)
# SUBS(COMBO1913,  "optimization ",  KC_O, KC_P, KC_Z)
# SUBS(COMBO1914,  "where's ",  KC_QUOT, KC_H, KC_R)
# SUBS(COMBO1915,  "rejection ",  KC_E, KC_J, KC_R)
# SUBS(COMBO1916,  "citizen ",  KC_C, KC_E, KC_Z)
# SUBS(COMBO1917,  "this question ",  KC_H, KC_Q, KC_T)
# SUBS(COMBO1918,  "to recognize ",  KC_N, KC_T, KC_Z)
# SUBS(COMBO1919,  "questions about ",  KC_B, KC_Q, KC_U)
# SUBS(COMBO1920,  "you've got to ",  KC_QUOT, KC_G, KC_U)
# SUBS(COMBO1921,  "analyz",  KC_BSPC, KC_Y, KC_Z)
# SUBS(COMBO1922,  "Jesus Christ ",  KC_C, KC_E, KC_J)
# SUBS(COMBO1923,  "the Japanese ",  KC_E, KC_J, KC_P)
# SUBS(COMBO1924,  "the world's ",  KC_QUOT, KC_D, KC_L)
# SUBS(COMBO1925,  "sixty ",  KC_S, KC_X, KC_Y)
# SUBS(COMBO1926,  "you're not going to ",  KC_QUOT, KC_N, KC_R)
# SUBS(COMBO1927,  "his mother's ",  KC_QUOT, KC_M, KC_R)
# SUBS(COMBO1928,  "walked over to the ",  KC_K, KC_R, KC_V)
# SUBS(COMBO1929,  "I'd be ",  KC_QUOT, KC_B, KC_E)
# SUBS(COMBO1930,  "jumping ",  KC_I, KC_J, KC_P)
# SUBS(COMBO1931,  "and he'd ",  KC_QUOT, KC_A, KC_D)
# SUBS(COMBO1932,  "eezing ",  KC_E, KC_I, KC_Z)
# SUBS(COMBO1933,  "the size of the ",  KC_O, KC_S, KC_Z)
# SUBS(COMBO1934,  "the existing ",  KC_G, KC_S, KC_X)
# SUBS(COMBO1935,  "switzerland",  KC_L, KC_W, KC_Z)
# SUBS(COMBO1936,  "subjectiv",  KC_J, KC_S, KC_V)
# SUBS(COMBO1937,  "New Zealand ",  KC_SPC, KC_W, KC_Z)
# SUBS(COMBO1938,  "flexibility ",  KC_B, KC_F, KC_X)
# SUBS(COMBO1939,  "and there's ",  KC_QUOT, KC_A, KC_R)
# SUBS(COMBO1940,  "inequality ",  KC_L, KC_Q, KC_Y)
# SUBS(COMBO1941,  "workshop",  KC_K, KC_P, KC_W)
# SUBS(COMBO1942,  "globalization ",  KC_B, KC_L, KC_Z)
# SUBS(COMBO1943,  "just have ",  KC_J, KC_U, KC_V)
# SUBS(COMBO1944,  "and she'd ",  KC_QUOT, KC_A, KC_N)
# SUBS(COMBO1945,  "recognizing ",  KC_O, KC_R, KC_Z)
# SUBS(COMBO1946,  "exhibit ",  KC_B, KC_I, KC_X)
# SUBS(COMBO1947,  "but there's ",  KC_QUOT, KC_R, KC_U)
# SUBS(COMBO1948,  "quarterly ",  KC_L, KC_Q, KC_R)
# SUBS(COMBO1949,  "exhaustion ",  KC_H, KC_U, KC_X)
# SUBS(COMBO1950,  "the Queen ",  KC_BSPC, KC_H, KC_Q)
# SUBS(COMBO1951,  "analyze",  KC_L, KC_Y, KC_Z)
# SUBS(COMBO1952,  "we've been ",  KC_QUOT, KC_N, KC_V)
# SUBS(COMBO1953,  "I'd never ",  KC_QUOT, KC_I, KC_R)
# SUBS(COMBO1954,  "zero ",  KC_E, KC_O, KC_Z)
# SUBS(COMBO1955,  "what's the matter ",  KC_QUOT, KC_E, KC_W)
# SUBS(COMBO1956,  "of the author's imagination ",  KC_QUOT, KC_F, KC_T)
# SUBS(COMBO1957,  "I'm here ",  KC_QUOT, KC_E, KC_R)
# SUBS(COMBO1958,  "the woman's ",  KC_QUOT, KC_A, KC_E)
# SUBS(COMBO1959,  "quiring ",  KC_SPC, KC_G, KC_Q)
# SUBS(COMBO1960,  "exclusively ",  KC_V, KC_X, KC_Y)
# SUBS(COMBO1961,  "authorized ",  KC_D, KC_U, KC_Z)
# SUBS(COMBO1962,  "projection",  KC_J, KC_P, KC_R)
# SUBS(COMBO1963,  "just for ",  KC_F, KC_J, KC_R)
# SUBS(COMBO1964,  "the requirements of ",  KC_M, KC_O, KC_Q)
# SUBS(COMBO1965,  "husband's ",  KC_QUOT, KC_D, KC_U)
# SUBS(COMBO1966,  "subjective ",  KC_B, KC_J, KC_U)
# SUBS(COMBO1967,  "if she'd ",  KC_QUOT, KC_D, KC_F)
# SUBS(COMBO1968,  "did not even know ",  KC_I, KC_K, KC_V)
# SUBS(COMBO1969,  "zone ",  KC_E, KC_N, KC_Z)
# SUBS(COMBO1970,  "it's okay ",  KC_QUOT, KC_A, KC_K)
# SUBS(COMBO1971,  "the consequences of ",  KC_H, KC_O, KC_Q)
# SUBS(COMBO1972,  "a consequence ",  KC_N, KC_Q, KC_S)
# SUBS(COMBO1973,  "you're doing ",  KC_QUOT, KC_D, KC_R)
# SUBS(COMBO1974,  "quoted ",  KC_D, KC_O, KC_Q)
# SUBS(COMBO1975,  "I've got a ",  KC_QUOT, KC_A, KC_G)
# SUBS(COMBO1976,  "would've ",  KC_QUOT, KC_U, KC_V)
# SUBS(COMBO1977,  "just in case ",  KC_E, KC_I, KC_J)
# SUBS(COMBO1978,  "requiring ",  KC_G, KC_Q, KC_U)
# SUBS(COMBO1979,  "just have to ",  KC_A, KC_J, KC_V)
# SUBS(COMBO1980,  "he'd have ",  KC_QUOT, KC_E, KC_V)
# SUBS(COMBO1981,  "the questions ",  KC_H, KC_Q, KC_U)
# SUBS(COMBO1982,  "you'd better ",  KC_QUOT, KC_D, KC_E)
# SUBS(COMBO1983,  "know you're ",  KC_QUOT, KC_K, KC_W)
# SUBS(COMBO1984,  "it'll be ",  KC_QUOT, KC_B, KC_L)
# SUBS(COMBO1985,  "freezing ",  KC_F, KC_I, KC_Z)
# SUBS(COMBO1986,  "qualification",  KC_C, KC_L, KC_Q)
# SUBS(COMBO1987,  "in question ",  KC_I, KC_O, KC_Q)
# SUBS(COMBO1988,  "exquisite ",  KC_SPC, KC_Q, KC_X)
# SUBS(COMBO1989,  "affect the overall learning experience ",  KC_O, KC_V, KC_X)
# SUBS(COMBO1990,  "exhibition ",  KC_B, KC_N, KC_X)
# SUBS(COMBO1991,  "of Jesus ",  KC_E, KC_F, KC_J)
# SUBS(COMBO1992,  "and I'm not ",  KC_QUOT, KC_D, KC_M)
# SUBS(COMBO1993,  "specialized ",  KC_C, KC_L, KC_Z)
# SUBS(COMBO1994,  "the patient's ",  KC_SPC, KC_QUOT, KC_P)
# SUBS(COMBO1995,  "jealousy ",  KC_A, KC_J, KC_Y)
# SUBS(COMBO1996,  "if that's ",  KC_QUOT, KC_A, KC_F)
# SUBS(COMBO1997,  "as quickly as ",  KC_K, KC_Q, KC_Y)
# SUBS(COMBO1998,  "gazing ",  KC_G, KC_N, KC_Z)
# SUBS(COMBO1999,  "be expected ",  KC_B, KC_C, KC_X)
# SUBS(COMBO2000,  "if subsequent rights restrictions require ",  KC_B, KC_I, KC_Q)
